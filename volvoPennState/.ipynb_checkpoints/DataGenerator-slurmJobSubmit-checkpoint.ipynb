# %% [markdown]
# ## !pip install SQLAlchemy
# # !pip install pyspark
# # !pip install jupysql duckdb duckdb-engine
# # !pip install delta-spark
# # !pip install py4j
# # !pip install -q findspark
# # conda install -c conda-forge submitit
# # conda install corn, nbconvert
# # !pip install graphviz
# # !pip install hydra-core
# # !pip install hydra-submitit-launcher
# # !pip install submitit
# # !pip install covalent-slurm-plugin
# # !pip install ipynb-py-convert

# %%
# %env JAVA_HOME=/usr/lib/jvm/java-11-openjdk-11.0.24.0.8-3.el8.x86_64
# %env PATH=/storage/home/yqf5148/work/anaconda3/envs/volvopennstate-env/bin:storage/icds/swst/deployed/production/20220813/apps/anaconda3/2021.05_gcc-8.5.0/bin:/usr/lib/jvm/java-11-openjdk-11.0.24.0.8-3.el8.x86_64/bin/java:/usr/local/bin:/usr/bin:/usr/local/sbin:/usr/sbin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin
# Out:
# env: JAVA_HOME=/usr/lib/jvm/java-11-openjdk-11.0.24.0.8-3.el8.x86_64
# env: PATH=/storage/home/yqf5148/work/anaconda3/envs/volvopennstate-env/bin:storage/icds/swst/deployed/production/20220813/apps/anaconda3/2021.05_gcc-8.5.0/bin:/usr/lib/jvm/java-11-openjdk-11.0.24.0.8-3.el8.x86_64/bin/java:/usr/local/bin:/usr/bin:/usr/local/sbin:/usr/sbin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin

# %%
import findspark
import pandas as pd
import numpy as np

import pyspark as psk
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql import functions as f
from pyspark.sql import Row
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql import DataFrame
from pyspark.sql.functions import *

# import submitit

import time as t 
from datetime import date, datetime, timedelta
from joblib import Parallel, delayed
import multiprocessing
from functools import reduce  
from math import modf
import sqlite3
import os
import sys

from delta import * 
from delta.tables import *
from delta import configure_spark_with_delta_pip
# import covalent as ct

import subprocess
import re

findspark.init()
findspark.find()

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# os.environ['PYDEVD_DISABLE_FILE_VALIDATION']=1

spark = SparkSession.builder \
       .master("local[2]") \
       .appName("MyApp") \
       .config("spark.driver.maxResultSize", "20g")\
       .config("spark.driver.memory", "100g")\
       .getOrCreate()
sc = spark.sparkContext

# sqlContext = SQLContext(sc)


spark.sql("set spark.sql.legacy.timeParserPolicy=LEGACY")    #To resolve the error for p1075_38 to_timestamp formating: You may get a different result due to the upgrading to Spark >= 3.0: Fail to parse '1/2/2019 20:40:00' in the new parser. You can set spark.sql.legacy.timeParserPolicy to LEGACY to restore the behavior before Spark 3.0, or set to CORRECTED and treat it as an invalid datetime string.
spark.sql("set spark.sql.execution.arrow.enabled=false")
# Out:
# ps: /storage/icds/RISE/sw8/anaconda/anaconda3/envs/tensorflow/lib/libuuid.so.1: no version information available (required by /usr/lib64/libblkid.so.1)
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/09/03 01:31:16 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/09/03 01:31:16 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/09/03 01:31:19 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# DataFrame[key: string, value: string]

# %%
spark.read.option("header",True) \
          .csv("/storage/home/yqf5148/work/volvoPennState/data/dataset/VINs_data.csv") \
          .createOrReplaceTempView("VINs_data")

spark.read.option("header",True) \
          .csv("/storage/home/yqf5148/work/volvoPennState/PopulationWithChassisId.csv") \
          .createOrReplaceTempView("population")
# Out:
# 24/09/03 01:31:21 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
def whether_thisVIN_data_already_generated(thisVIN): 
    df_VINs_data = spark.sql("SELECT * FROM VINs_data")
    df_VINs_data = df_VINs_data.toDF("VIN", "TOTAL_ROWS")
    df_VINs_data_p = df_VINs_data.toPandas()
    for index, row in df_VINs_data_p.iterrows():
        if row['VIN'] == thisVIN:
          return 1
    return 0 

# Function to submit a SLURM job and return the job ID
def submit_job(script_path, thisVIN, account='vuh14_dibbs_sc', partition='SLA Prio'):
    submit_command = f"sbatch --account={account} --partition={partition} {script_path} {thisVIN}"
    print("The submit command for the submitted job is: ")
    print(submit_command)
    result = subprocess.run(submit_command, shell=True, capture_output=True, text=True)
    if result.returncode == 0:
        job_id = re.findall(r'\d+', result.stdout)[0]
        print(f"Job {job_id} submitted successfully.")
        return job_id
    else:
        print("Job submission failed.")
        return None

# Function to check the status of multiple jobs
def check_jobs_status(job_ids):
    jobs_running = set(job_ids)
    while jobs_running:
        for job_id in list(jobs_running):
            status_command = f"squeue -j {job_id}"
            result = subprocess.run(status_command, shell=True, capture_output=True, text=True)
            if not result.stdout:  # If the job is no longer in the queue
                print(f"Job {job_id} completed.")
                jobs_running.remove(job_id)
        if jobs_running:
            print("Some jobs are still running...")
            print(jobs_running)
            t.sleep(1)  # Check every 5 seconds

# Function to retrieve job outputs
def get_jobs_output(output_files):
    for output_file in output_files:
        try:
            with open(output_file, "r") as file:
                output = file.read()
            print(f"Output from {output_file}:")
            print(output)
        except FileNotFoundError:
            print(f"Output file {output_file} not found.")

    

df_all_pop_VINs = spark.sql('select distinct VIN from population ') 
df_generated_pop_VINs = spark.sql('select * from VINs_data') 
df_generated_pop_VINs = df_generated_pop_VINs.toDF("VIN", "TOTAL_ROWS")


print("size of df_all_pop_VINs={0}, df_generated_pop_VINs = {1}".format(df_all_pop_VINs.count(), df_generated_pop_VINs.count()))    
    
if (df_all_pop_VINs.count() > df_generated_pop_VINs.count()):   

    population_num_of_rows = ' LIMIT 100 '

    df_pop_VINs = spark.sql('select distinct VIN from population order by RANDOM() {0} '.format(population_num_of_rows))  #where VIN like "'"1M1AN02Y2JM028028"'" ') #   % or VIN like "'"1M1AN02YXJM027581%"'" or VIN like "'"%"'" or VIN like "'"1M1AN02Y9JM027295%"'" {0} '.format(population_num_of_rows))   #  All rows in population table is: 322178
    df_pop_VINs_p = df_pop_VINs.toPandas()


    # Submitting multiple jobs
    job_ids = []
    output_files = []
    for index, row in df_pop_VINs_p.iterrows():
        thisVIN = row['VIN']
        if whether_thisVIN_data_already_generated(thisVIN)==1:
            print("This VIN = {}'s data is already generated.".format(thisVIN))
            continue
        else:
            print("This VIN = {}'s data is not generated.".format(thisVIN))
            aCurrentVIN = thisVIN 
            df_filtered_population_for_this_VIN = df_all_pop_VINs.filter(f.col('VIN')==aCurrentVIN)
            script_path = f"/storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh"  # Assuming different scripts for each job
            output_file = f"/storage/home/yqf5148/work/volvoPennState/Jobs/log_test/result_{thisVIN}.txt"  # Assuming different output files for each job
            job_id = submit_job(script_path, thisVIN)

            if job_id:
                job_ids.append(job_id)
                output_files.append(output_file)

    # Check the status of all jobs
    check_jobs_status(job_ids)

    # Retrieve and print outputs for all jobs
    get_jobs_output(output_files)

    # # check if there is any remaining VIN for which we have not generated data. In other words, if  df_all_pop_VINs > df_generated_pop_VINs we should continue generating dsata for the remaining VINs.
    # df_generated_pop_VINs = spark.sql('select * from VINs_data') 
    # df_generated_pop_VINs = df_generated_pop_VINs.toDF("VIN", "TOTAL_ROWS")
# Out:
# size of df_all_pop_VINs=322178, df_generated_pop_VINs = 24
# This VIN = 4V4NC9EG3JN898643's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EG3JN898643
# Job 19875063 submitted successfully.
# This VIN = 4V4NC9EJ5KN210896's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EJ5KN210896
# Job 19875064 submitted successfully.
# This VIN = 1M1AN4GY6LM018279's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN4GY6LM018279
# Job 19875065 submitted successfully.
# This VIN = 4V4NC9EH6KN904736's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH6KN904736
# Job 19875066 submitted successfully.
# This VIN = 4V4NC9EH5MN265607's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH5MN265607
# Job 19875067 submitted successfully.
# This VIN = 4V4NC9EJ2LN213451's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EJ2LN213451
# Job 19875068 submitted successfully.
# This VIN = 4V4NC9EH7JN897780's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH7JN897780
# Job 19875071 submitted successfully.
# This VIN = 4V4NC9EH6FN190693's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH6FN190693
# Job 19875072 submitted successfully.
# This VIN = 4V4NC9EH4LN251034's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH4LN251034
# Job 19875073 submitted successfully.
# This VIN = 1M1AN4GY5MM021756's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN4GY5MM021756
# Job 19875074 submitted successfully.
# This VIN = 1M2LR2GC7KM001183's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2LR2GC7KM001183
# Job 19875075 submitted successfully.
# This VIN = 4V4N99EH4GN954220's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4N99EH4GN954220
# Job 19875076 submitted successfully.
# This VIN = 1M2AX04C4FM024934's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX04C4FM024934
# Job 19875077 submitted successfully.
# This VIN = 4V4NC9EH7GN180708's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH7GN180708
# Job 19875078 submitted successfully.
# This VIN = 1M1PN4GY9LM005262's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1PN4GY9LM005262
# Job 19875079 submitted successfully.
# This VIN = 4V4NC9EH1JN993775's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH1JN993775
# Job 19875080 submitted successfully.
# This VIN = 4V4NC9EH9FN918636's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH9FN918636
# Job 19875081 submitted successfully.
# This VIN = 1M1AN4GY9LM017773's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN4GY9LM017773
# Job 19875082 submitted successfully.
# This VIN = 1M2AX09C4HM035251's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX09C4HM035251
# Job 19875083 submitted successfully.
# This VIN = 4V4NC9EH8KN240102's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH8KN240102
# Job 19875084 submitted successfully.
# This VIN = 4V4NC9EJ6GN962985's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EJ6GN962985
# Job 19875085 submitted successfully.
# This VIN = 4V4NC9EJ4HN967667's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EJ4HN967667
# Job 19875086 submitted successfully.
# This VIN = 1M2TE2GCXNM006586's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2TE2GCXNM006586
# Job 19875087 submitted successfully.
# This VIN = 4V4W19EGXLN245496's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4W19EGXLN245496
# Job 19875088 submitted successfully.
# This VIN = 1M2AX13C9GM031905's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX13C9GM031905
# Job 19875089 submitted successfully.
# This VIN = 1M2AW02Y1FM048691's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AW02Y1FM048691
# Job 19875090 submitted successfully.
# This VIN = 1M2TE2GC0LM004438's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2TE2GC0LM004438
# Job 19875091 submitted successfully.
# This VIN = 1M2AX09C5JM035832's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX09C5JM035832
# Job 19875092 submitted successfully.
# This VIN = 4V4WC9EJ9MN282594's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4WC9EJ9MN282594
# Job 19875093 submitted successfully.
# This VIN = 1M2AU02CXFM009642's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AU02CXFM009642
# Job 19875094 submitted successfully.
# This VIN = 1M2GR3GC4MM021367's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2GR3GC4MM021367
# Job 19875095 submitted successfully.
# This VIN = 1M1PN4GY9MM007823's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1PN4GY9MM007823
# Job 19875096 submitted successfully.
# This VIN = 1M1AW09Y9GM053391's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW09Y9GM053391
# Job 19875097 submitted successfully.
# This VIN = 4V4NC9EHXFN178644's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EHXFN178644
# Job 19875098 submitted successfully.
# This VIN = 1M1PN4GY9LM001762's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1PN4GY9LM001762
# Job 19875099 submitted successfully.
# This VIN = 1M2AX09C5JM040416's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX09C5JM040416
# Job 19875100 submitted successfully.
# This VIN = 4V4NC9EH6JN889010's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH6JN889010
# Job 19875101 submitted successfully.
# This VIN = 1M1AW09Y1GM077894's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW09Y1GM077894
# Job 19875102 submitted successfully.
# This VIN = 1M1AW09YXHM079693's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW09YXHM079693
# Job 19875103 submitted successfully.
# This VIN = 1M2TE2GC9MM005749's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2TE2GC9MM005749
# Job 19875104 submitted successfully.
# This VIN = 1M2AX07C2HM035705's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX07C2HM035705
# Job 19875105 submitted successfully.
# This VIN = 1M1PN4GY8LM006841's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1PN4GY8LM006841
# Job 19875106 submitted successfully.
# This VIN = 1M2GR2GCXLM015727's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2GR2GCXLM015727
# Job 19875107 submitted successfully.
# This VIN = 4V4NC9EH4LN269372's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH4LN269372
# Job 19875108 submitted successfully.
# This VIN = 1M1AN07Y7GM023733's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN07Y7GM023733
# Job 19875109 submitted successfully.
# This VIN = 4V4NC9EH3KN902751's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH3KN902751
# Job 19875110 submitted successfully.
# This VIN = 4V4NC9EH7GN929216's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH7GN929216
# Job 19875111 submitted successfully.
# This VIN = 4V4NC9EHXKN192473's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EHXKN192473
# Job 19875124 submitted successfully.
# This VIN = 4V4NC9EH8HN994447's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH8HN994447
# Job 19875127 submitted successfully.
# This VIN = 1M1AN07Y2HM023723's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN07Y2HM023723
# Job 19875128 submitted successfully.
# This VIN = 4V4NC9EH9GN945613's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH9GN945613
# Job 19875129 submitted successfully.
# This VIN = 1M2AX07C9HM036804's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX07C9HM036804
# Job 19875130 submitted successfully.
# This VIN = 1M2GR3NC2LM001328's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2GR3NC2LM001328
# Job 19875131 submitted successfully.
# This VIN = 4V4N19EH9KN871897's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4N19EH9KN871897
# Job 19875132 submitted successfully.
# This VIN = 4V4WC9EH2KN214518's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4WC9EH2KN214518
# Job 19875133 submitted successfully.
# This VIN = 1M2AV04C9GM014178's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AV04C9GM014178
# Job 19875134 submitted successfully.
# This VIN = 1M1PN4GY0KM003009's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1PN4GY0KM003009
# Job 19875135 submitted successfully.
# This VIN = 4V4NC9EH3KN207654's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH3KN207654
# Job 19875139 submitted successfully.
# This VIN = 4V4MC9EH5GN966289's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4MC9EH5GN966289
# Job 19875141 submitted successfully.
# This VIN = 4V4NC9EH9KN201342's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH9KN201342
# Job 19875142 submitted successfully.
# This VIN = 4V4NC9EG5FN183211's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EG5FN183211
# Job 19875143 submitted successfully.
# This VIN = 4V4NC9EH8LN221275's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH8LN221275
# Job 19875145 submitted successfully.
# This VIN = 1M1AN4GY3LM018952's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN4GY3LM018952
# Job 19875147 submitted successfully.
# This VIN = 1M1AW21Y9GM056542's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW21Y9GM056542
# Job 19875148 submitted successfully.
# This VIN = 4V4MC9EH7GN927770's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4MC9EH7GN927770
# Job 19875149 submitted successfully.
# This VIN = 1M2GR4GC3MM021916's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2GR4GC3MM021916
# Job 19875150 submitted successfully.
# This VIN = 1M2GR2GC3MM016333's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2GR2GC3MM016333
# Job 19875151 submitted successfully.
# This VIN = 1M1AW02Y4JM087143's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW02Y4JM087143
# Job 19875152 submitted successfully.
# This VIN = 4V4NC9EH7KN195797's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH7KN195797
# Job 19875153 submitted successfully.
# This VIN = 4V4NC9EH8GN975220's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH8GN975220
# Job 19875154 submitted successfully.
# This VIN = 1M2AX13C4GM034680's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX13C4GM034680
# Job 19875155 submitted successfully.
# This VIN = 1M2GR2GC3MM020916's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2GR2GC3MM020916
# Job 19875156 submitted successfully.
# This VIN = 1M1AN07Y0JM027470's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN07Y0JM027470
# Job 19875157 submitted successfully.
# This VIN = 1M2AX04C9FM021446's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX04C9FM021446
# Job 19875158 submitted successfully.
# This VIN = 1M2TE2GCXMM005369's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2TE2GCXMM005369
# Job 19875160 submitted successfully.
# This VIN = 1M1AW09Y8FM048133's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW09Y8FM048133
# Job 19875161 submitted successfully.
# This VIN = 4V4WC9EG3MN287116's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4WC9EG3MN287116
# Job 19875162 submitted successfully.
# This VIN = 4V4NC9EH3KN212045's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH3KN212045
# Job 19875163 submitted successfully.
# This VIN = 4V4NC9EH0LN214188's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH0LN214188
# Job 19875164 submitted successfully.
# This VIN = 1M1AN3GY8LM016625's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN3GY8LM016625
# Job 19875165 submitted successfully.
# This VIN = 1M2GR2GC4LM019059's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2GR2GC4LM019059
# Job 19875166 submitted successfully.
# This VIN = 4V4NC9EHXMN254652's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EHXMN254652
# Job 19875167 submitted successfully.
# This VIN = 1M1AW07Y2GM059553's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW07Y2GM059553
# Job 19875168 submitted successfully.
# This VIN = 4V4NC9EH2GN951947's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH2GN951947
# Job 19875169 submitted successfully.
# This VIN = 4V4NC9EJ7FN923062's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EJ7FN923062
# Job 19875170 submitted successfully.
# This VIN = 1M1AW21Y0GM077098's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW21Y0GM077098
# Job 19875171 submitted successfully.
# This VIN = 4V4NC9EH2LN222924's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH2LN222924
# Job 19875172 submitted successfully.
# This VIN = 4V4NC9EH8MN282417's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH8MN282417
# Job 19875173 submitted successfully.
# This VIN = 4V4NC9EH7JN886777's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH7JN886777
# Job 19875174 submitted successfully.
# This VIN = 4V4NC9EJ8GN950448's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EJ8GN950448
# Job 19875175 submitted successfully.
# This VIN = 1M1AN07Y4HM025893's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN07Y4HM025893
# Job 19875176 submitted successfully.
# This VIN = 4V4NC9EG8MN271747's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EG8MN271747
# Job 19875177 submitted successfully.
# This VIN = 1M1PN4GY1MM007590's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1PN4GY1MM007590
# Job 19875178 submitted successfully.
# This VIN = 4V4NC9EH4KN201457's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH4KN201457
# Job 19875179 submitted successfully.
# This VIN = 1M1AW07Y7GM060715's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW07Y7GM060715
# Job 19875180 submitted successfully.
# This VIN = 4V4NC9EH8KN212428's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH8KN212428
# Job 19875181 submitted successfully.
# This VIN = 4V4NC9EG7JN891663's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EG7JN891663
# Job 19875182 submitted successfully.
# This VIN = 4V4NC9EH7GN948378's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH7GN948378
# Job 19875183 submitted successfully.
# This VIN = 4V4NC9EH1LN222154's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH1LN222154
# Job 19875184 submitted successfully.
# This VIN = 4V4W19EH0LN259884's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4W19EH0LN259884
# Job 19875185 submitted successfully.
# Some jobs are still running...
# {'19875086', '19875095', '19875109', '19875092', '19875098', '19875180', '19875162', '19875066', '19875154', '19875097', '19875181', '19875183', '19875182', '19875130', '19875084', '19875153', '19875075', '19875083', '19875178', '19875073', '19875168', '19875132', '19875106', '19875151', '19875148', '19875131', '19875082', '19875096', '19875124', '19875087', '19875065', '19875072', '19875171', '19875172', '19875167', '19875145', '19875108', '19875155', '19875164', '19875139', '19875152', '19875163', '19875094', '19875071', '19875074', '19875170', '19875103', '19875134', '19875090', '19875085', '19875100', '19875093', '19875174', '19875169', '19875099', '19875177', '19875184', '19875107', '19875078', '19875128', '19875111', '19875105', '19875089', '19875166', '19875067', '19875088', '19875141', '19875068', '19875076', '19875150', '19875110', '19875080', '19875161', '19875142', '19875176', '19875081', '19875135', '19875173', '19875157', '19875063', '19875165', '19875149', '19875102', '19875129', '19875077', '19875156', '19875179', '19875079', '19875133', '19875185', '19875147', '19875175', '19875143', '19875104', '19875127', '19875064', '19875091', '19875158', '19875160', '19875101'}
# Some jobs are still running...
# {'19875086', '19875095', '19875109', '19875092', '19875098', '19875180', '19875162', '19875066', '19875154', '19875097', '19875181', '19875183', '19875182', '19875130', '19875084', '19875153', '19875075', '19875083', '19875178', '19875073', '19875168', '19875132', '19875106', '19875151', '19875148', '19875131', '19875082', '19875096', '19875124', '19875087', '19875065', '19875072', '19875171', '19875172', '19875167', '19875145', '19875108', '19875155', '19875164', '19875139', '19875152', '19875163', '19875094', '19875071', '19875074', '19875170', '19875103', '19875134', '19875090', '19875085', '19875100', '19875093', '19875174', '19875169', '19875099', '19875177', '19875184', '19875107', '19875078', '19875128', '19875111', '19875105', '19875089', '19875166', '19875067', '19875088', '19875141', '19875068', '19875076', '19875150', '19875110', '19875080', '19875161', '19875142', '19875176', '19875081', '19875135', '19875173', '19875157', '19875063', '19875165', '19875149', '19875102', '19875129', '19875077', '19875156', '19875179', '19875079', '19875133', '19875185', '19875147', '19875175', '19875143', '19875104', '19875127', '19875064', '19875091', '19875158', '19875160', '19875101'}
# Some jobs are still running...
# {'19875086', '19875095', '19875109', '19875092', '19875098', '19875180', '19875162', '19875066', '19875154', '19875097', '19875181', '19875183', '19875182', '19875130', '19875084', '19875153', '19875075', '19875083', '19875178', '19875073', '19875168', '19875132', '19875106', '19875151', '19875148', '19875131', '19875082', '19875096', '19875124', '19875087', '19875065', '19875072', '19875171', '19875172', '19875167', '19875145', '19875108', '19875155', '19875164', '19875139', '19875152', '19875163', '19875094', '19875071', '19875074', '19875170', '19875103', '19875134', '19875090', '19875085', '19875100', '19875093', '19875174', '19875169', '19875099', '19875177', '19875184', '19875107', '19875078', '19875128', '19875111', '19875105', '19875089', '19875166', '19875067', '19875088', '19875141', '19875068', '19875076', '19875150', '19875110', '19875080', '19875161', '19875142', '19875176', '19875081', '19875135', '19875173', '19875157', '19875063', '19875165', '19875149', '19875102', '19875129', '19875077', '19875156', '19875179', '19875079', '19875133', '19875185', '19875147', '19875175', '19875143', '19875104', '19875127', '19875064', '19875091', '19875158', '19875160', '19875101'}
# Some jobs are still running...
# {'19875086', '19875095', '19875109', '19875092', '19875098', '19875180', '19875162', '19875066', '19875154', '19875097', '19875181', '19875183', '19875182', '19875130', '19875084', '19875153', '19875075', '19875083', '19875178', '19875073', '19875168', '19875132', '19875106', '19875151', '19875148', '19875131', '19875082', '19875096', '19875124', '19875087', '19875065', '19875072', '19875171', '19875172', '19875167', '19875145', '19875108', '19875155', '19875164', '19875139', '19875152', '19875163', '19875094', '19875071', '19875074', '19875170', '19875103', '19875134', '19875090', '19875085', '19875100', '19875093', '19875174', '19875169', '19875099', '19875177', '19875184', '19875107', '19875078', '19875128', '19875111', '19875105', '19875089', '19875166', '19875067', '19875088', '19875141', '19875068', '19875076', '19875150', '19875110', '19875080', '19875161', '19875142', '19875176', '19875081', '19875135', '19875173', '19875157', '19875063', '19875165', '19875149', '19875102', '19875129', '19875077', '19875156', '19875179', '19875079', '19875133', '19875185', '19875147', '19875175', '19875143', '19875104', '19875127', '19875064', '19875091', '19875158', '19875160', '19875101'}

# %%
display(df_pop_VINs_p)
