# %%
# !pip install SQLAlchemy
# !pip install pyspark
# !pip install jupysql duckdb duckdb-engine
# !pip install delta-spark
# !pip install py4j
# !pip install -q findspark
# conda install -c conda-forge submitit 
# conda install corn, nbconvert
# !pip install graphviz
# !pip install hydra-core
# !pip install hydra-submitit-launcher
# !pip install submitit
# !pip install covalent-slurm-plugin
# !pip install ipynb-py-convert

# %%
# %env JAVA_HOME=/usr/lib/jvm/java-11-openjdk-11.0.24.0.8-3.el8.x86_64
# %env PATH=/storage/home/yqf5148/work/anaconda3/envs/volvopennstate-env/bin:storage/icds/swst/deployed/production/20220813/apps/anaconda3/2021.05_gcc-8.5.0/bin:/usr/lib/jvm/java-11-openjdk-11.0.24.0.8-3.el8.x86_64/bin/java:/usr/local/bin:/usr/bin:/usr/local/sbin:/usr/sbin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin
# Out:
# env: JAVA_HOME=/usr/lib/jvm/java-11-openjdk-11.0.24.0.8-3.el8.x86_64
# env: PATH=/storage/home/yqf5148/work/anaconda3/envs/volvopennstate-env/bin:storage/icds/swst/deployed/production/20220813/apps/anaconda3/2021.05_gcc-8.5.0/bin:/usr/lib/jvm/java-11-openjdk-11.0.24.0.8-3.el8.x86_64/bin/java:/usr/local/bin:/usr/bin:/usr/local/sbin:/usr/sbin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin:/storage/icds/tools/bin:/storage/sys/slurm/bin

# %%
import findspark
import pandas as pd
import numpy as np

import pyspark as psk
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql import functions as f
from pyspark.sql import Row
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql import DataFrame
from pyspark.sql.functions import *

# import submitit

import time as t 
from datetime import date, datetime, timedelta
from joblib import Parallel, delayed
import multiprocessing
from functools import reduce  
from math import modf
import sqlite3
import os
import sys

from delta import * 
from delta.tables import *
from delta import configure_spark_with_delta_pip
# import covalent as ct

import subprocess
import re

findspark.init()
findspark.find()

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# os.environ['PYDEVD_DISABLE_FILE_VALIDATION']=1

spark = SparkSession.builder \
       .master("local[2]") \
       .appName("MyApp") \
       .config("spark.driver.maxResultSize", "20g")\
       .config("spark.driver.memory", "100g")\
       .getOrCreate()
sc = spark.sparkContext

# sqlContext = SQLContext(sc)


spark.sql("set spark.sql.legacy.timeParserPolicy=LEGACY")    #To resolve the error for p1075_38 to_timestamp formating: You may get a different result due to the upgrading to Spark >= 3.0: Fail to parse '1/2/2019 20:40:00' in the new parser. You can set spark.sql.legacy.timeParserPolicy to LEGACY to restore the behavior before Spark 3.0, or set to CORRECTED and treat it as an invalid datetime string.
spark.sql("set spark.sql.execution.arrow.enabled=false")
# Out:
# ps: /storage/icds/RISE/sw8/anaconda/anaconda3/envs/tensorflow/lib/libuuid.so.1: no version information available (required by /usr/lib64/libblkid.so.1)
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/08/19 02:37:49 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/08/19 02:37:49 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/08/19 02:37:49 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 24/08/19 02:37:49 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 24/08/19 02:37:49 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 24/08/19 02:37:49 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.
# 24/08/19 02:37:51 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# DataFrame[key: string, value: string]

# %%
spark.read.option("header",True) \
          .csv("/storage/home/yqf5148/work/volvoPennState/data/dataset/VINs_data.csv") \
          .createOrReplaceTempView("VINs_data")

spark.read.option("header",True) \
          .csv("/storage/home/yqf5148/work/volvoPennState/PopulationWithChassisId.csv") \
          .createOrReplaceTempView("population")
# Out:
# 24/08/19 02:37:54 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
def whether_thisVIN_data_already_generated(thisVIN): 
    df_VINs_data = spark.sql("SELECT * FROM VINs_data")
    df_VINs_data = df_VINs_data.toDF("VIN", "TOTAL_ROWS")
    df_VINs_data_p = df_VINs_data.toPandas()
    for index, row in df_VINs_data_p.iterrows():
        if row['VIN'] == thisVIN:
          return 1
    return 0 

# Function to submit a SLURM job and return the job ID
def submit_job(script_path, thisVIN):
    submit_command = f"sbatch {script_path} {thisVIN}"
    print("The submit command for the submitted job is: ")
    print(submit_command)
    result = subprocess.run(submit_command, shell=True, capture_output=True, text=True)
    if result.returncode == 0:
        job_id = re.findall(r'\d+', result.stdout)[0]
        print(f"Job {job_id} submitted successfully.")
        return job_id
    else:
        print("Job submission failed.")
        return None

# Function to check the status of multiple jobs
def check_jobs_status(job_ids):
    jobs_running = set(job_ids)
    while jobs_running:
        for job_id in list(jobs_running):
            status_command = f"squeue -j {job_id}"
            result = subprocess.run(status_command, shell=True, capture_output=True, text=True)
            if not result.stdout:  # If the job is no longer in the queue
                print(f"Job {job_id} completed.")
                jobs_running.remove(job_id)
        if jobs_running:
            print("Some jobs are still running...")
            print(jobs_running)
            t.sleep(1)  # Check every 5 seconds

# Function to retrieve job outputs
def get_jobs_output(output_files):
    for output_file in output_files:
        try:
            with open(output_file, "r") as file:
                output = file.read()
            print(f"Output from {output_file}:")
            print(output)
        except FileNotFoundError:
            print(f"Output file {output_file} not found.")

    

df_all_pop_VINs = spark.sql('select distinct VIN from population ') 
df_generated_pop_VINs = spark.sql('select * from VINs_data') 
df_generated_pop_VINs = df_generated_pop_VINs.toDF("VIN", "TOTAL_ROWS")


print("size of df_all_pop_VINs={0}, df_generated_pop_VINs = {1}".format(df_all_pop_VINs.count(), df_generated_pop_VINs.count()))    
    
if (df_all_pop_VINs.count() > df_generated_pop_VINs.count()):   

    population_num_of_rows = ' LIMIT 100 '

    df_pop_VINs = spark.sql('select distinct VIN from population order by RANDOM() {0} '.format(population_num_of_rows))  #where VIN like "'"1M1AN02Y2JM028028"'" ') #   % or VIN like "'"1M1AN02YXJM027581%"'" or VIN like "'"%"'" or VIN like "'"1M1AN02Y9JM027295%"'" {0} '.format(population_num_of_rows))   #  All rows in population table is: 322178
    df_pop_VINs_p = df_pop_VINs.toPandas()


    # Submitting multiple jobs
    job_ids = []
    output_files = []
    for index, row in df_pop_VINs_p.iterrows():
        thisVIN = row['VIN']
        if whether_thisVIN_data_already_generated(thisVIN)==1:
            print("This VIN = {}'s data is already generated.".format(thisVIN))
            continue
        else:
            print("This VIN = {}'s data is not generated.".format(thisVIN))
            aCurrentVIN = thisVIN 
            df_filtered_population_for_this_VIN = df_all_pop_VINs.filter(f.col('VIN')==aCurrentVIN)
            script_path = f"/storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh"  # Assuming different scripts for each job
            output_file = f"/storage/home/yqf5148/work/volvoPennState/Jobs/log_test/result_{thisVIN}.txt"  # Assuming different output files for each job
            job_id = submit_job(script_path, thisVIN)

            if job_id:
                job_ids.append(job_id)
                output_files.append(output_file)

    # Check the status of all jobs
    check_jobs_status(job_ids)

    # Retrieve and print outputs for all jobs
    get_jobs_output(output_files)

    # # check if there is any remaining VIN for which we have not generated data. In other words, if  df_all_pop_VINs > df_generated_pop_VINs we should continue generating dsata for the remaining VINs.
    # df_generated_pop_VINs = spark.sql('select * from VINs_data') 
    # df_generated_pop_VINs = df_generated_pop_VINs.toDF("VIN", "TOTAL_ROWS")
# Out:
# size of df_all_pop_VINs=322178, df_generated_pop_VINs = 545
# This VIN = 4V4NC9EG4MN290120's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EG4MN290120
# Job 18610337 submitted successfully.
# This VIN = 4V5KC9DG6HN977895's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V5KC9DG6HN977895
# Job 18610338 submitted successfully.
# This VIN = 1M2AU02C5FM009371's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AU02C5FM009371
# Job 18610339 submitted successfully.
# This VIN = 1M2LR06C8HM001207's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2LR06C8HM001207
# Job 18610340 submitted successfully.
# This VIN = 4V4NC9EH3FN918518's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH3FN918518
# Job 18610341 submitted successfully.
# This VIN = 1M2AV04C8FM013327's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AV04C8FM013327
# Job 18610342 submitted successfully.
# This VIN = 1M2TE2GC6LM003844's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2TE2GC6LM003844
# Job 18610343 submitted successfully.
# This VIN = 1M1AW02Y0HM080748's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW02Y0HM080748
# Job 18610344 submitted successfully.
# This VIN = 1M1AW07Y1GM053632's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW07Y1GM053632
# Job 18610345 submitted successfully.
# This VIN = 4V4NC9EH7HN991975's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH7HN991975
# Job 18610346 submitted successfully.
# This VIN = 1M1AW09Y5FM051989's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW09Y5FM051989
# Job 18610347 submitted successfully.
# This VIN = 4V4NC9EH1GN948358's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH1GN948358
# Job 18610348 submitted successfully.
# This VIN = 4V4NC9EHXKN906814's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EHXKN906814
# Job 18610349 submitted successfully.
# This VIN = 4V4NC9EJ4FN182563's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EJ4FN182563
# Job 18610350 submitted successfully.
# This VIN = 1M2AU02C3FM008946's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AU02C3FM008946
# Job 18610351 submitted successfully.
# This VIN = 4V4NC9EG7GN966709's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EG7GN966709
# Job 18610352 submitted successfully.
# This VIN = 4V4NC9EH7KN201470's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH7KN201470
# Job 18610353 submitted successfully.
# This VIN = 1M1AW09Y7GM077768's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW09Y7GM077768
# Job 18610354 submitted successfully.
# This VIN = 1M1PN4GYXLM005688's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1PN4GYXLM005688
# Job 18610355 submitted successfully.
# This VIN = 4V4NC9EH4KN207887's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH4KN207887
# Job 18610356 submitted successfully.
# This VIN = 1M2GR2GC9LM011717's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2GR2GC9LM011717
# Job 18610357 submitted successfully.
# This VIN = 4V5KC9EH5MN272300's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V5KC9EH5MN272300
# Job 18610358 submitted successfully.
# This VIN = 4V4NC9EH0JN896227's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH0JN896227
# Job 18610359 submitted successfully.
# This VIN = 4V4NC9EH1GN966987's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH1GN966987
# Job 18610360 submitted successfully.
# This VIN = 4V4NC9EHXFN934487's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EHXFN934487
# Job 18610361 submitted successfully.
# This VIN = 1M2AX04C1HM036798's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX04C1HM036798
# Job 18610362 submitted successfully.
# This VIN = 4V4NC9EH3LN256287's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH3LN256287
# Job 18610363 submitted successfully.
# This VIN = 4V5RC9EH4KN200435's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V5RC9EH4KN200435
# Job 18610364 submitted successfully.
# This VIN = 1M1AW09Y3GM077718's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW09Y3GM077718
# Job 18610365 submitted successfully.
# This VIN = 4V4NC9EH1MN286471's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH1MN286471
# Job 18610366 submitted successfully.
# This VIN = 1M2AX04C4HM033863's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX04C4HM033863
# Job 18610367 submitted successfully.
# This VIN = 4V4MC9EH1HN987240's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4MC9EH1HN987240
# Job 18610368 submitted successfully.
# This VIN = 1M2AX07CXJM040091's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX07CXJM040091
# Job 18610369 submitted successfully.
# This VIN = 1M1AW21Y4GM051071's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW21Y4GM051071
# Job 18610370 submitted successfully.
# This VIN = 1M1AN07Y0FM020932's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN07Y0FM020932
# Job 18610371 submitted successfully.
# This VIN = 1M1AW02Y6FM050232's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW02Y6FM050232
# Job 18610372 submitted successfully.
# This VIN = 1M1AW07Y1FM049482's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW07Y1FM049482
# Job 18610373 submitted successfully.
# This VIN = 1M2TE1AC3MM001084's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2TE1AC3MM001084
# Job 18610374 submitted successfully.
# This VIN = 1M2AX01C6JM003001's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX01C6JM003001
# Job 18610375 submitted successfully.
# This VIN = 4V4N99DG7GN947769's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4N99DG7GN947769
# Job 18610376 submitted successfully.
# This VIN = 1M1AN3AY7MM002435's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN3AY7MM002435
# Job 18610377 submitted successfully.
# This VIN = 4V4NC9EH7GN958179's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH7GN958179
# Job 18610378 submitted successfully.
# This VIN = 4V4NC9EH6LN195386's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH6LN195386
# Job 18610379 submitted successfully.
# This VIN = 4V4NC9EH7KN205843's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH7KN205843
# Job 18610380 submitted successfully.
# This VIN = 1M2LR02C2GM001160's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2LR02C2GM001160
# Job 18610381 submitted successfully.
# This VIN = 1M2AX04CXJM039964's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX04CXJM039964
# Job 18610382 submitted successfully.
# This VIN = 1M1AN07Y5GM022435's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN07Y5GM022435
# Job 18610383 submitted successfully.
# This VIN = 1M1AW07Y5HM081189's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW07Y5HM081189
# Job 18610384 submitted successfully.
# This VIN = 4V4NC9EH5FN189132's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH5FN189132
# Job 18610385 submitted successfully.
# This VIN = 1M2GR4GC9KM004289's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2GR4GC9KM004289
# Job 18610386 submitted successfully.
# This VIN = 4V4NB9EH3JN998589's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NB9EH3JN998589
# Job 18610387 submitted successfully.
# This VIN = 4V4NC9EH9MN280658's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH9MN280658
# Job 18610388 submitted successfully.
# This VIN = 1M1AW02Y2FM048459's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW02Y2FM048459
# Job 18610389 submitted successfully.
# This VIN = 1M2AX04C9GM031895's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX04C9GM031895
# Job 18610390 submitted successfully.
# This VIN = 4V4NC9EH0FN921215's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH0FN921215
# Job 18610391 submitted successfully.
# This VIN = 1M1AW07YXFM051795's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW07YXFM051795
# Job 18610392 submitted successfully.
# This VIN = 4V4N99EH5FN922178's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4N99EH5FN922178
# Job 18610393 submitted successfully.
# This VIN = 4V4NC9EH1KN902991's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH1KN902991
# Job 18610394 submitted successfully.
# This VIN = 1M2AV04C2GM015902's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AV04C2GM015902
# Job 18610395 submitted successfully.
# This VIN = 4V5R99DG4FN189742's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V5R99DG4FN189742
# Job 18610396 submitted successfully.
# This VIN = 1M1AW02Y7GM055263's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW02Y7GM055263
# Job 18610397 submitted successfully.
# This VIN = 4V4WC9EHXKN241501's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4WC9EHXKN241501
# Job 18610398 submitted successfully.
# This VIN = 1M1AW21Y9FM047533's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW21Y9FM047533
# Job 18610399 submitted successfully.
# This VIN = 1M2AX09C3GM028743's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX09C3GM028743
# Job 18610400 submitted successfully.
# This VIN = 4V4NC9EH1HN974475's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH1HN974475
# Job 18610401 submitted successfully.
# This VIN = 1M1AN4HY9NM003180's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN4HY9NM003180
# Job 18610402 submitted successfully.
# This VIN = 1M1PN4GY6LM004313's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1PN4GY6LM004313
# Job 18610403 submitted successfully.
# This VIN = 4V4NC9EG4HN971478's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EG4HN971478
# Job 18610404 submitted successfully.
# This VIN = 4V4NC9EH9KN874096's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH9KN874096
# Job 18610405 submitted successfully.
# This VIN = 4V4N39EG7FN927858's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4N39EG7FN927858
# Job 18610406 submitted successfully.
# This VIN = 1M2AX13C7GM034916's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX13C7GM034916
# Job 18610407 submitted successfully.
# This VIN = 4V4NC9EHXLN237784's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EHXLN237784
# Job 18610408 submitted successfully.
# This VIN = 1M1AW02Y4GM077057's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW02Y4GM077057
# Job 18610409 submitted successfully.
# This VIN = 1M2GR4GC0KM001748's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2GR4GC0KM001748
# Job 18610410 submitted successfully.
# This VIN = 4V4NC9EH3LN224827's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH3LN224827
# Job 18610411 submitted successfully.
# This VIN = 1M2AX07C5GM027287's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX07C5GM027287
# Job 18610412 submitted successfully.
# This VIN = 1M2AX13C8HM037275's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX13C8HM037275
# Job 18610413 submitted successfully.
# This VIN = 1M2AX13C3FM028044's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX13C3FM028044
# Job 18610414 submitted successfully.
# This VIN = 4V4W39EG5KN226153's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4W39EG5KN226153
# Job 18610415 submitted successfully.
# This VIN = 1M2AX09C8JM039342's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX09C8JM039342
# Job 18610416 submitted successfully.
# This VIN = 1M2AV02C0FM011798's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AV02C0FM011798
# Job 18610417 submitted successfully.
# This VIN = 1M2AX13C4JM042737's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX13C4JM042737
# Job 18610418 submitted successfully.
# This VIN = 4V4NC9EH2FN187810's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH2FN187810
# Job 18610419 submitted successfully.
# This VIN = 4V4NC9EH0MN270374's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH0MN270374
# Job 18610420 submitted successfully.
# This VIN = 1M2TE1GC9KM001658's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2TE1GC9KM001658
# Job 18610421 submitted successfully.
# This VIN = 4V4NC9EJ0FN189865's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EJ0FN189865
# Job 18610422 submitted successfully.
# This VIN = 1M1AN4GY6KM008351's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AN4GY6KM008351
# Job 18610423 submitted successfully.
# This VIN = 1M1AX07Y8JM039134's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AX07Y8JM039134
# Job 18610424 submitted successfully.
# This VIN = 1M1AW31Y9GM078790's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M1AW31Y9GM078790
# Job 18610425 submitted successfully.
# This VIN = 1M2LR02C5GM001203's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2LR02C5GM001203
# Job 18610426 submitted successfully.
# This VIN = 1M2AX13C8FM029397's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AX13C8FM029397
# Job 18610427 submitted successfully.
# This VIN = 4V4NC9EJXJN887151's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EJXJN887151
# Job 18610428 submitted successfully.
# This VIN = 1M2AV02C2JM017515's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2AV02C2JM017515
# Job 18610429 submitted successfully.
# This VIN = 4V4NC9EH0NN282574's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH0NN282574
# Job 18610430 submitted successfully.
# This VIN = 4V4WC9EH9LN246125's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4WC9EH9LN246125
# Job 18610431 submitted successfully.
# This VIN = 4V4WC9EG9LN239571's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4WC9EG9LN239571
# Job 18610432 submitted successfully.
# This VIN = 4V4NC9EH9LN256228's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EH9LN256228
# Job 18610433 submitted successfully.
# This VIN = 4V4NC9EHXKN210065's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EHXKN210065
# Job 18610434 submitted successfully.
# This VIN = 1M2GR3GC9LM010444's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 1M2GR3GC9LM010444
# Job 18610435 submitted successfully.
# This VIN = 4V4NC9EJ6GN949847's data is not generated.
# The submit command for the submitted job is:
# sbatch /storage/home/yqf5148/work/volvoPennState/Jobs/submit.sh 4V4NC9EJ6GN949847
# Job 18610436 submitted successfully.
# Some jobs are still running...
# {'18610404', '18610363', '18610424', '18610400', '18610375', '18610340', '18610423', '18610378', '18610392', '18610432', '18610398', '18610390', '18610389', '18610406', '18610342', '18610338', '18610399', '18610352', '18610407', '18610420', '18610348', '18610360', '18610374', '18610337', '18610346', '18610413', '18610386', '18610357', '18610382', '18610418', '18610405', '18610427', '18610356', '18610379', '18610354', '18610353', '18610436', '18610415', '18610368', '18610426', '18610411', '18610414', '18610383', '18610358', '18610395', '18610429', '18610373', '18610409', '18610344', '18610385', '18610384', '18610345', '18610350', '18610359', '18610351', '18610425', '18610377', '18610422', '18610397', '18610366', '18610434', '18610387', '18610393', '18610341', '18610402', '18610369', '18610371', '18610401', '18610339', '18610372', '18610365', '18610381', '18610408', '18610376', '18610347', '18610416', '18610430', '18610435', '18610388', '18610362', '18610370', '18610394', '18610403', '18610396', '18610349', '18610343', '18610391', '18610380', '18610410', '18610421', '18610355', '18610428', '18610364', '18610419', '18610433', '18610367', '18610412', '18610431', '18610361', '18610417'}
