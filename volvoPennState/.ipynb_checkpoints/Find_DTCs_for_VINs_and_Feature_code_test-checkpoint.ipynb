# %%
import pandas as pd
import pyspark as psk
from pyspark.sql import SparkSession
import time as t  
from pyspark.sql.types import *
from pyspark.sql import functions as f
from pyspark.sql import Row  
from functools import reduce
from pyspark.sql.types import StructType, StructField, StringType
from datetime import date, datetime, timedelta
from joblib import Parallel, delayed
import multiprocessing
from functools import reduce  # For Python 3.x
from pyspark.sql import DataFrame
import numpy as np
from math import modf
import sqlite3
from pyspark.sql.functions import *
from pyspark import SparkContext
from delta import * 
from delta.tables import *
from delta import configure_spark_with_delta_pip
from pyspark.sql.functions import unix_timestamp
from datetime import date, datetime, timedelta
sc = SparkContext("local", "Simple App")



# Create SparkSession 
spark = SparkSession.builder.master("local[1]")\
                        .appName("SparkByExamples.com")\
                        .getOrCreate()

# %%
spark.sql("set spark.sql.legacy.timeParserPolicy=LEGACY")    #To resolve the error for p1075_38 to_timestamp formating: You may get a different result due to the upgrading to Spark >= 3.0: Fail to parse '1/2/2019 20:40:00' in the new parser. You can set spark.sql.legacy.timeParserPolicy to LEGACY to restore the behavior before Spark 3.0, or set to CORRECTED and treat it as an invalid datetime string.

spark.read.option("header",True) \
          .csv("P1075_38.csv") \
          .createOrReplaceTempView("p1075_38")  #VIN = '1M1AW01Y3FM007792' ").show()  #AND

spark.sql("SELECT * FROM p1075_38 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()  #_C0 IS NOT NULL AND MESSAGE_ID IS NOT NULL AND FAULT_DATE_TIME IS NOT NULL AND FAULT_STATUS IS NOT NULL").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+

# %%
spark.read.option("header",True) \
          .csv("P1075_75.csv") \
          .createOrReplaceTempView("p1075_75")  

spark.sql("SELECT * FROM p1075_75 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+

# %%
spark.read.option("header",True) \
          .csv("P1075_77.csv") \
          .createOrReplaceTempView("p1075_77")  

spark.sql("SELECT * FROM p1075_77 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+

# %%
spark.read.option("header",True) \
          .csv("P1075_86.csv") \
          .createOrReplaceTempView("p1075_86")  

spark.sql("SELECT * FROM p1075_86 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +------+--------------------+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+-------------------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |   _c0|                 VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|         PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +------+--------------------+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+-------------------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |229363|"4V4NC9EH8HN96166...|  26.39687|       14.64881|                62.07615|                       NA|       45|        NA|          NA|             4|   off|   183.2|          218.53|         0|        NA|                     NA|          NA|          16463.73|                          NA|            NA|              NA|        False|                      inactive|                          False|            0.33333|                     ok|                        0.33333|            14.1|        580.38125|          NA|     14.619804|         regenerationNotNe...|                           NA|       off|                          none|                               55|                  NA|                     100|                      88|                 74.075|            23.015|                 off|                 off|                      off|             off|              0|2020-02-19 08:27:41|                            Y|          null|                        null|         null|                      null|                            null|                     null|                     null|                    null|                 null|                            null|     null|                null|      null|        null|               null|           null|           null|              null|               null|                   null|         null|         null|           null|
# +------+--------------------+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+-------------------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+

# %%
spark.read.option("header",True) \
          .csv("P1075_92.csv") \
          .createOrReplaceTempView("p1075_92")  

spark.sql("SELECT * FROM p1075_92 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+

# %%
spark.read.option("header",True) \
          .csv("P1075_94.csv") \
          .createOrReplaceTempView("p1075_94")  

spark.sql("SELECT * FROM p1075_94 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+

# %%
spark.read.option("header",True) \
          .csv("P0401_faults.csv") \
          .createOrReplaceTempView("p0401_faults")  

spark.sql("SELECT * FROM p0401_faults WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +-------+---------+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |    _c0|      VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +-------+---------+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |3110413|4V4NC9EH7|      null|           null|                    null|                     null|     null|      null|        null|          null|  null|    null|            null|      null|      null|                   null|        null|              null|                        null|          null|            null|         null|                          null|                           null|               null|                   null|                           null|            null|             null|        null|          null|                         null|                         null|      null|                          null|                             null|                null|                    null|                    null|                   null|              null|                null|                null|                     null|            null|           null|      null|                         null|          null|                        null|         null|                      null|                            null|                     null|                     null|                    null|                 null|                            null|     null|                null|      null|        null|               null|           null|           null|              null|               null|                   null|         null|         null|           null|
# +-------+---------+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+

# %%
spark.read.option("header",True) \
          .csv("P2457_faults.csv") \
          .createOrReplaceTempView("p2457_faults")  

spark.sql("SELECT * FROM p2457_faults WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+

# %%
spark.sql("SELECT * FROM p1075_38 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p1075_75 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p1075_77 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p1075_86 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p1075_92 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p1075_94 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p0401_faults WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p2457_faults WHERE VIN = '1M1AW01Y9FM007831'").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
#
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
#
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
#
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
#
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
#
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
#
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
#
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# |_c0|VIN|MESSAGE_ID|FAULT_DATE_TIME|FAULT_OCCURENCE_LATITUDE|FAULT_OCCURENCE_LONGITUDE|CITY_NAME|STATE_NAME|COMPONENT_ID|COMPONENT_TYPE|ECU_ID|ECU_TYPE|MAIN_SOFTWARE_ID|DST_PARM_1|DST_PARM_2|FAILURE_MODE_IDENTIFIER|FAULT_STATUS|TOTAL_ENGINE_HOURS|TOTAL_VEHICLE_DISTANCE_MILES|ROAD_SPEED_MPH|ENGINE_SPEED_RPM|GEAR_POSITION|BRAKE_APPLICATION_PRESSURE_PSI|ACCELERATOR_PEDEL_POSITION_PERC|BOOST_PRESSURE_PERC|INTAKE_AIR_PRESSURE_PSI|AMBIENT_BARAMETRIC_PRESSURE_PSI|OIL_PRESSURE_PSI|FUEL_PRESSURE_PSI|LOAD_PERCENT|PERCENT_OF_EGR|DPF_DIFFERENTIAL_PRESSURE_PSI|ENGINE_THROTTLE_POSITION_PERC|FAN_STATUS|COOLANT_TEMPERATURE_FAHRENHEIT|ENGINE_OIL_TEMPERATURE_FAHRENHEIT|STEERING_WHEEL_ANGLE|VEHICLE_TIME_IN_TOP_GEAR|VEHICLE_FUEL_IN_TOP_GEAR|VEHICLE_TIME_IN_DRIVING|TOTAL_VEHICLE_FUEL|VEHICLE_FUEL_IN_IDLE|VEHICLE_TIME_IN_IDLE|VEHICLE_TIME_SPENT_PARKED|ENGINE_IN_DERATE|ENGINE_SHUTDOWN|PTO_ACTIVE|TIME_LEFT_TO_TORQUE_REDUCTION|SCR_INDUCEMENT|TIME_LEFT_TO_SPEED_REDUCTION|BATTERY_LEVEL|ENGINE_EXHAUST_TEMPERATURE|ENGINE_PARTICULATE_TRAP_PRESSURE|ENGINE_CRANKCASE_PRESSURE|REGENERATION_FILTER_STATE|GROSS_COMBINATION_WEIGHT|PARKING_BRAKE_ENGAGED|SCR_OPERATOR_INDUCEMENT_SEVERITY|OIL_LEVEL|ENGINE_TOURQUE_LEVEL|FUEL_LEVEL|ADBLUE_LEVEL|AMBIENT_TEMPERATURE|FAULT_FILTER_ID|RED_LAMP_STATUS|YELLOW_LAMP_STATUS|PROTECT_LAMP_STATUS|MALFUNCTION_LAMP_STATUS|ASIST_CASE_ID|LOAD_DATETIME|DV_CURRENT_FLAG|
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------------------+--------------------------------+-------------------------+-------------------------+------------------------+---------------------+--------------------------------+---------+--------------------+----------+------------+-------------------+---------------+---------------+------------------+-------------------+-----------------------+-------------+-------------+---------------+

# %%
spark.read.option("header",True) \
          .csv("Population.csv") \
          .createOrReplaceTempView("population")

# %%
spark.sql('select VIN from population where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_38 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_75 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_77 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_86 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_92 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_94 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p0401_faults where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p2457_faults where VIN like "'"1M1AN02Y%"'"  ').show()
# Out:
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y5JM027293|
# |1M1AN02Y7JM027294|
# |1M1AN02Y1JM027257|
# |1M1AN02Y5JM027259|
# |1M1AN02Y1JM027260|
# |1M1AN02Y3JM027292|
# |1M1AN02Y3JM027258|
# |1M1AN02Y3JM027261|
# |1M1AN02Y9JM027295|
# |1M1AN02Y0JM027296|
# |1M1AN02Y5JM027309|
# |1M1AN02Y5JM028072|
# |1M1AN02Y3JM028068|
# |1M1AN02Y0JM028030|
# |1M1AN02Y3JM028071|
# |1M1AN02Y5JM028069|
# |1M1AN02Y2JM028093|
# |1M1AN02Y0JM028092|
# |1M1AN02Y1JM028070|
# |1M1AN02Y0KM028482|
# +-----------------+
# only showing top 20 rows
#
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y4JM028029|
# |1M1AN02Y9JM027295|
# |1M1AN02Y2JM028028|
# |1M1AN02Y0JM028027|
# |1M1AN02Y2JM028336|
# |1M1AN02Y7JM027294|
# |1M1AN02Y5JM027309|
# |1M1AN02Y0JM028335|
# |1M1AN02Y5KM028381|
# |1M1AN02YXJM027788|
# +-----------------+
#
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y0JM028335|
# |1M1AN02Y5KM028381|
# |1M1AN02Y0JM028318|
# |1M1AN02YXJM027788|
# |1M1AN02Y4KM028484|
# |1M1AN02Y7JM027294|
# |1M1AN02Y8KM028486|
# |1M1AN02Y5JM027309|
# |1M1AN02Y4JM028290|
# |1M1AN02Y8KM027614|
# |1M1AN02Y2JM028028|
# |1M1AN02Y0JM028027|
# |1M1AN02Y8JM027790|
# +-----------------+
#
# +---+
# |VIN|
# +---+
# +---+
#
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y3JM027261|
# |1M1AN02Y9JM028687|
# |1M1AN02YXJM027581|
# |1M1AN02Y6JM028338|
# +-----------------+
#
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y3KM027617|
# |1M1AN02Y0JM028027|
# +-----------------+
#
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y9JM027295|
# |1M1AN02Y3KM027617|
# |1M1AN02Y2JM028336|
# +-----------------+
#
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y5JM027259|
# |1M1AN02YXKM028585|
# |1M1AN02Y3KM027617|
# |1M1AN02Y6KM028485|
# |1M1AN02Y2KM028581|
# |1M1AN02Y4KM028582|
# |1M1AN02YXJM027581|
# |1M1AN02Y5JM027293|
# |1M1AN02Y0JM028724|
# |1M1AN02Y6KM028583|
# |1M1AN02Y3JM027258|
# |1M1AN02Y0KM028482|
# |1M1AN02Y4JM028726|
# +-----------------+
#
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y8KM028584|
# |1M1AN02Y5KM028381|
# |1M1AN02Y0JM027573|
# |1M1AN02Y0JM028724|
# |1M1AN02Y2JM028322|
# +-----------------+

# %%
spark.sql('select VIN from population where VIN like "'"1M1AN02Y7JM027294%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_38 where VIN like "'"1M1AW01Y7GM008820%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_75 where VIN like "'"1M1AN02Y7JM027294%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_77 where VIN like "'"1M1AN02Y7JM027294%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_86 where VIN like "'"1M1AN02Y7JM027294%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_92 where VIN like "'"1M1AN02Y7JM027294%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_94 where VIN like "'"1M1AN02Y7JM027294%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p0401_faults where VIN like "'"1M1AN02Y7JM027294%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p2457_faults where VIN like "'"1M1AN02Y7JM027294%"'"  ').show()
# Out:
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y7JM027294|
# +-----------------+
#
# +----------------+------------+
# | FAULT_DATE_TIME|FAULT_STATUS|
# +----------------+------------+
# | 12/4/2019 12:39|           N|
# |12/18/2019 20:00|           N|
# | 12/9/2019 19:07|           N|
# | 1/28/2020 18:20|           Y|
# | 3/21/2019 23:36|           Y|
# |12/17/2019 19:00|           N|
# |  1/21/2020 6:10|           Y|
# | 12/14/2019 8:44|           N|
# | 11/7/2019 18:40|           N|
# | 1/10/2020 10:24|           Y|
# | 1/15/2020 22:53|           Y|
# |12/30/2019 22:39|           Y|
# |12/10/2019 22:08|           Y|
# | 1/10/2020 22:18|           Y|
# |  1/6/2020 18:15|           N|
# | 11/6/2019 19:59|           Y|
# |12/20/2019 20:48|           Y|
# | 1/16/2020 22:24|           Y|
# | 3/21/2019 23:44|           N|
# | 11/30/2019 0:50|           N|
# +----------------+------------+
# only showing top 20 rows
#
# +-------------------+------------+
# |    FAULT_DATE_TIME|FAULT_STATUS|
# +-------------------+------------+
# |2020-12-28 18:38:36|           I|
# |2020-12-28 18:42:27|           I|
# |2020-12-28 18:43:01|           Y|
# |2020-12-16 13:45:13|           Y|
# |2020-12-24 07:31:22|           Y|
# |2020-12-16 13:44:06|           Y|
# |2020-12-16 13:45:51|           N|
# |2020-12-28 18:51:57|           N|
# |2020-12-28 18:45:01|           N|
# |2020-12-16 13:43:59|           I|
# |2020-12-16 13:45:13|           I|
# |2020-12-24 07:42:31|           N|
# |2020-12-20 12:06:18|           N|
# |2020-12-16 13:43:20|           Y|
# |2020-12-28 18:47:33|           Y|
# |2020-12-23 17:00:46|           I|
# |2020-12-23 16:58:16|           N|
# |2020-12-23 19:01:00|           N|
# |2020-12-28 18:38:49|           N|
# |2020-12-28 18:40:42|           Y|
# +-------------------+------------+
# only showing top 20 rows
#
# +---------------+------------+
# |FAULT_DATE_TIME|FAULT_STATUS|
# +---------------+------------+
# +---------------+------------+
#
# +---------------+------------+
# |FAULT_DATE_TIME|FAULT_STATUS|
# +---------------+------------+
# +---------------+------------+
#
# +---------------+------------+
# |FAULT_DATE_TIME|FAULT_STATUS|
# +---------------+------------+
# +---------------+------------+
#
# +---------------+------------+
# |FAULT_DATE_TIME|FAULT_STATUS|
# +---------------+------------+
# +---------------+------------+
#
# +---------------+------------+
# |FAULT_DATE_TIME|FAULT_STATUS|
# +---------------+------------+
# +---------------+------------+
#
# +---------------+------------+
# |FAULT_DATE_TIME|FAULT_STATUS|
# +---------------+------------+
# +---------------+------------+

# %%
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_38 where VIN like "'"1M1AW01Y7GM008820%"'"  ').sort(f.to_timestamp(f.col('FAULT_DATE_TIME'))).show()
df_dtc_type_for_this_VIN = spark.sql('select * from p1075_38 where VIN like "'"1M1AW01Y7GM008820%"'"  ').sort(f.to_timestamp(f.col('FAULT_DATE_TIME')))
dtc_type = "p1075_38"
# Out:
# +----------------+------------+
# | FAULT_DATE_TIME|FAULT_STATUS|
# +----------------+------------+
# | 12/4/2019 12:39|           N|
# |  12/4/2019 5:46|           Y|
# |  1/10/2020 6:19|           N|
# | 10/22/2019 2:50|           Y|
# |12/10/2019 22:08|           Y|
# |12/31/2019 21:49|           Y|
# |12/18/2019 20:00|           N|
# | 1/10/2020 22:18|           Y|
# | 12/9/2019 19:07|           N|
# |  1/6/2020 18:15|           N|
# | 1/28/2020 18:20|           Y|
# | 11/6/2019 19:59|           Y|
# | 3/21/2019 23:36|           Y|
# |12/20/2019 20:48|           Y|
# |12/17/2019 19:00|           N|
# | 1/16/2020 22:24|           Y|
# |  1/21/2020 6:10|           Y|
# | 3/21/2019 23:44|           N|
# | 12/14/2019 8:44|           N|
# | 11/30/2019 0:50|           N|
# +----------------+------------+
# only showing top 20 rows

# %%
def fix_problem_of_fault_date_time_with_no_seconds(df, dtc_type):
    if dtc_type=="p1075_38":
       return f.to_timestamp(f.concat(df.FAULT_DATE_TIME, lit(":00")), "M/d/yyyy HH:mm:ss")
    else:
       return f.to_timestamp(df.FAULT_DATE_TIME, "M/d/yyyy HH:mm:ss")

# %%
timeFmt = "M/d/yyyy HH:mm"

which_15_days_back = "first"
dtc_status = "Y"
fault_date_time_format='yyyy-MM-dd HH:mm:ss'
if dtc_type=="p1075_38":
    fault_date_time_format='M/d/yyyy HH:mm'


duration_end_date = '2020-01-31'

day_delta = timedelta(days = 1)
split_date = duration_end_date.split('-')

end_date = date(int(split_date[0]), int(split_date[1]), int(split_date[2]))
start_date = end_date - timedelta(days = 62)

if df_dtc_type_for_this_VIN.count() > 0 :
    df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan = df_dtc_type_for_this_VIN.filter((fix_problem_of_fault_date_time_with_no_seconds(df_dtc_type_for_this_VIN, dtc_type) > start_date) & (fix_problem_of_fault_date_time_with_no_seconds(df_dtc_type_for_this_VIN, dtc_type) < end_date))
    
    print("found number of DTC's that we want to calculate the duration for={}\n".format(df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan.count()))
    df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan = df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan.withColumn('dtc_alarms', f.concat(f.lit(which_15_days_back), f.lit("_15_days_back"))) 


    dtcs_with_all_statuses_df = df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan.alias("a").sort(f.to_timestamp(f.col('FAULT_DATE_TIME'), fault_date_time_format))
    dtcs_with_all_statuses_df['VIN','FAULT_STATUS', 'FAULT_DATE_TIME', f.to_timestamp(f.col('FAULT_DATE_TIME'), fault_date_time_format)].show()
    
    
    dtcs_with_all_statuses_df2 = dtcs_with_all_statuses_df

    # This one is also true to access the first row of pyspark dataframe    
#     headRowId = dtcs_with_all_statuses_df2.first()[0]

    headRowId = dtcs_with_all_statuses_df2.head()[0][0]
    dtcs_with_all_statuses_df2 = dtcs_with_all_statuses_df2.filter(f.col('_c0') != headRowId).fillna(0)
    
    tailRowId = dtcs_with_all_statuses_df.tail(1)[0][0]
    dtcs_with_all_statuses_df = dtcs_with_all_statuses_df.filter(f.col('_c0') != tailRowId).fillna(0)

    
    df1 = dtcs_with_all_statuses_df.toPandas()
    df2 = dtcs_with_all_statuses_df2.toPandas()

    column_names = ['VIN','FAULT_STATUS_CURRENT_DTC','FAULT_DATE_TIME_NEXT_ANY_DTC', 'FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC', 'FAULT_DATE_TIME_NEXT_ANY_DTC'] 
    my_temp_df = pd.concat([df1['VIN'], df1['FAULT_STATUS'], df2['FAULT_STATUS'], df1['FAULT_DATE_TIME'], df2['FAULT_DATE_TIME']], ignore_index=True, axis=1) #df1.rename(columns={'FAULT_STATUS':'FAULT_STATUS_CURRENT_DTC', 'FAULT_DATE_TIME':'FAULT_DATE_TIME_NEXT_ANY_DTC'}), df2.rename(columns={'FAULT_STATUS':'FAULT_DATE_TIME_NEXT_ANY_DTC', 'FAULT_DATE_TIME':'FAULT_DATE_TIME_NEXT_ANY_DTC'})
 
    my_temp_df.columns = column_names
    print(my_temp_df.count())
    display(my_temp_df)
    
    
    
    
    
    
#     my_temp_df = (   
#         df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan.alias("a").sort(f.to_timestamp(f.col('FAULT_DATE_TIME')))\
#         .join(
#             df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan.alias("b"),
#             [

#                 f.unix_timestamp(f.col('a.FAULT_DATE_TIME'), fault_date_time_format) < f.unix_timestamp(f.col('b.FAULT_DATE_TIME'), fault_date_time_format), 
#                 f.col("a.FAULT_STATUS") == f.lit(dtc_status)

#             ],
#             "INNER",
#         )\
#       .withColumn("FAULT_DATE_TIME_DIFF", (f.unix_timestamp(f.col("b.FAULT_DATE_TIME"), format=fault_date_time_format) - f.unix_timestamp(f.col("a.FAULT_DATE_TIME"), format=fault_date_time_format)))\
#       .withColumn("DURATION_IN_THIS_15_DAYS_BACK", f.when((f.to_timestamp(f.col('a.FAULT_DATE_TIME'), fault_date_time_format) >= start_date) & (f.to_timestamp(f.col('b.FAULT_DATE_TIME'), fault_date_time_format) <= end_date), (f.unix_timestamp("b.FAULT_DATE_TIME", format=timeFmt) - f.unix_timestamp("a.FAULT_DATE_TIME", format=timeFmt))))\
#       .sort(f.to_timestamp(f.col('a.FAULT_DATE_TIME')))\
#       .select(

#            f.col("a.FAULT_DATE_TIME").alias("FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC"),
#            f.col("b.FAULT_DATE_TIME").alias("FAULT_DATE_TIME_NEXT_ANY_DTC"),
#            f.col("FAULT_DATE_TIME_DIFF"),
#            f.col("DURATION_IN_THIS_15_DAYS_BACK"),
#            f.col("a.VIN").alias("VIN"),
#            f.col("a.FAULT_STATUS").alias("FAULT_STATUS_CURRENT_DTC"),
#            f.col("b.FAULT_STATUS").alias("FAULT_ANY_STATUS_NEXT_DTC"),


#          )
#      ).fillna(0).dropDuplicates(['VIN','FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC'])
# #     my_temp_df = my_temp_df.dropDuplicates(['VIN', 'FAULT_DATE_TIME_NEXT_ANY_DTC'])
    
#     m 
#     print("How many rows exists in the number of found DTCs of active status for this VIN = {} \n".format(my_temp_df.count()))
#     duration_of_specific_type_dtcs_for_this_VIN = my_temp_df.select(f.sum("DURATION_IN_THIS_15_DAYS_BACK")).fillna(0)  
#     print("The duration is equal to {}\n".format(duration_of_specific_type_dtcs_for_this_VIN.collect()[0][0]))
# else:
#     print("The duration is equal to zero\n")
# Out:
# found number of DTC's that we want to calculate the duration for=19
#
# +-----------------+------------+----------------+---------------------------------------------+
# |              VIN|FAULT_STATUS| FAULT_DATE_TIME|to_timestamp(FAULT_DATE_TIME, M/d/yyyy HH:mm)|
# +-----------------+------------+----------------+---------------------------------------------+
# |1M1AW01Y7GM008820|           N| 11/30/2019 0:50|                          2019-11-30 00:50:00|
# |1M1AW01Y7GM008820|           Y|  12/4/2019 5:46|                          2019-12-04 05:46:00|
# |1M1AW01Y7GM008820|           N| 12/4/2019 12:39|                          2019-12-04 12:39:00|
# |1M1AW01Y7GM008820|           N| 12/9/2019 19:07|                          2019-12-09 19:07:00|
# |1M1AW01Y7GM008820|           Y|12/10/2019 22:08|                          2019-12-10 22:08:00|
# |1M1AW01Y7GM008820|           N| 12/14/2019 8:44|                          2019-12-14 08:44:00|
# |1M1AW01Y7GM008820|           N|12/17/2019 19:00|                          2019-12-17 19:00:00|
# |1M1AW01Y7GM008820|           N|12/18/2019 20:00|                          2019-12-18 20:00:00|
# |1M1AW01Y7GM008820|           Y|12/20/2019 20:48|                          2019-12-20 20:48:00|
# |1M1AW01Y7GM008820|           Y|12/30/2019 22:39|                          2019-12-30 22:39:00|
# |1M1AW01Y7GM008820|           Y|12/31/2019 21:49|                          2019-12-31 21:49:00|
# |1M1AW01Y7GM008820|           N|  1/6/2020 18:15|                          2020-01-06 18:15:00|
# |1M1AW01Y7GM008820|           N|  1/10/2020 6:19|                          2020-01-10 06:19:00|
# |1M1AW01Y7GM008820|           Y| 1/10/2020 10:24|                          2020-01-10 10:24:00|
# |1M1AW01Y7GM008820|           Y| 1/10/2020 22:18|                          2020-01-10 22:18:00|
# |1M1AW01Y7GM008820|           Y| 1/15/2020 22:53|                          2020-01-15 22:53:00|
# |1M1AW01Y7GM008820|           Y| 1/16/2020 22:24|                          2020-01-16 22:24:00|
# |1M1AW01Y7GM008820|           Y|  1/21/2020 6:10|                          2020-01-21 06:10:00|
# |1M1AW01Y7GM008820|           Y| 1/28/2020 18:20|                          2020-01-28 18:20:00|
# +-----------------+------------+----------------+---------------------------------------------+
#
# VIN                                          18
# FAULT_STATUS_CURRENT_DTC                     18
# FAULT_DATE_TIME_NEXT_ANY_DTC                 19
# FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC    18
# FAULT_DATE_TIME_NEXT_ANY_DTC                 19
# dtype: int64
#                   VIN FAULT_STATUS_CURRENT_DTC FAULT_DATE_TIME_NEXT_ANY_DTC  \
# 0   1M1AW01Y7GM008820                        N                            N
# 1   1M1AW01Y7GM008820                        Y                            Y
# 2   1M1AW01Y7GM008820                        N                            N
# 3   1M1AW01Y7GM008820                        N                            N
# 4   1M1AW01Y7GM008820                        Y                            Y
# 5   1M1AW01Y7GM008820                        N                            N
# 6   1M1AW01Y7GM008820                        N                            N
# 7   1M1AW01Y7GM008820                        N                            N
# 8   1M1AW01Y7GM008820                        Y                            Y
# 9   1M1AW01Y7GM008820                        Y                            Y
# 10  1M1AW01Y7GM008820                        Y                            Y
# 11  1M1AW01Y7GM008820                        N                            N
# 12  1M1AW01Y7GM008820                        N                            N
# 13  1M1AW01Y7GM008820                        Y                            Y
# 14  1M1AW01Y7GM008820                        Y                            Y
# 15  1M1AW01Y7GM008820                        Y                            Y
# 16  1M1AW01Y7GM008820                        Y                            Y
# 17  1M1AW01Y7GM008820                        Y                            Y
# 18                NaN                      NaN                            Y
#
#    FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC FAULT_DATE_TIME_NEXT_ANY_DTC
# 0                            11/30/2019 0:50              11/30/2019 0:50
# 1                             12/4/2019 5:46               12/4/2019 5:46
# 2                            12/4/2019 12:39              12/4/2019 12:39
# 3                            12/9/2019 19:07              12/9/2019 19:07
# 4                           12/10/2019 22:08             12/10/2019 22:08
# 5                            12/14/2019 8:44              12/14/2019 8:44
# 6                           12/17/2019 19:00             12/17/2019 19:00
# 7                           12/18/2019 20:00             12/18/2019 20:00
# 8                           12/20/2019 20:48             12/20/2019 20:48
# 9                           12/30/2019 22:39             12/30/2019 22:39
# 10                          12/31/2019 21:49             12/31/2019 21:49
# 11                            1/6/2020 18:15               1/6/2020 18:15
# 12                            1/10/2020 6:19               1/10/2020 6:19
# 13                           1/10/2020 10:24              1/10/2020 10:24
# 14                           1/10/2020 22:18              1/10/2020 22:18
# 15                           1/15/2020 22:53              1/15/2020 22:53
# 16                           1/16/2020 22:24              1/16/2020 22:24
# 17                            1/21/2020 6:10               1/21/2020 6:10
# 18                                       NaN              1/28/2020 18:20
