# %%
# خیلی مهم: برای حل مشکل java gateway error گذشته از تعریف environment variable ها مانند JAVA_HOME در داخل Terminal در داخل خود notebook باید این سطر را یکبار اجرا کرد:

# %env JAVA_HOME=/usr/lib/jvm/java-11-openjdk-11.0.21.0.9-2.el8.x86_64
# Out:
# env: JAVA_HOME=/usr/lib/jvm/java-11-openjdk-11.0.21.0.9-2.el8.x86_64

# %%
import pandas as pd
import pyspark as psk
from pyspark.sql import SparkSession
import time as t  
from pyspark.sql.types import *
from pyspark.sql import functions as f
from pyspark.sql import Row  
from functools import reduce
from pyspark.sql.types import StructType, StructField, StringType
from datetime import date, datetime, timedelta
from joblib import Parallel, delayed
import multiprocessing
from functools import reduce  # For Python 3.x
from pyspark.sql import DataFrame
import numpy as np
from math import modf
import sqlite3
from pyspark.sql.functions import *
from pyspark import SparkContext
from delta import * 
from delta.tables import *
from delta import configure_spark_with_delta_pip
from pyspark.sql.functions import unix_timestamp
from datetime import date, datetime, timedelta
from pyspark.sql.functions import monotonically_increasing_id
sc = SparkContext("local", "Simple App")



# Create SparkSession 
spark = SparkSession.builder.master("local[1]")\
                        .appName("SparkByExamples.com")\
                        .getOrCreate()

# %%
spark.conf.set("spark.sql.execution.arrow.enabled","true")
spark.sql("set spark.sql.legacy.timeParserPolicy=LEGACY")    #To resolve the error for p1075_38 to_timestamp formating: You may get a different result due to the upgrading to Spark >= 3.0: Fail to parse '1/2/2019 20:40:00' in the new parser. You can set spark.sql.legacy.timeParserPolicy to LEGACY to restore the behavior before Spark 3.0, or set to CORRECTED and treat it as an invalid datetime string.

spark.read.option("header",True) \
          .csv("P1075_38.csv") \
          .createOrReplaceTempView("p1075_38")  #VIN = '1M1AW01Y3FM007792' ").show()  #AND

spark.sql("SELECT * FROM p1075_38 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()  #_C0 IS NOT NULL AND MESSAGE_ID IS NOT NULL AND FAULT_DATE_TIME IS NOT NULL AND FAULT_STATUS IS NOT NULL").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+------------------------
# ...

# %%
spark.read.option("header",True) \
          .csv("P1075_75.csv") \
          .createOrReplaceTempView("p1075_75")  

spark.sql("SELECT * FROM p1075_75 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+------------------------
# ...

# %%
spark.read.option("header",True) \
          .csv("P1075_77.csv") \
          .createOrReplaceTempView("p1075_77")  

spark.sql("SELECT * FROM p1075_77 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+------------------------
# ...

# %%
spark.read.option("header",True) \
          .csv("P1075_86.csv") \
          .createOrReplaceTempView("p1075_86")  

spark.sql("SELECT * FROM p1075_86 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +------+--------------------+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+-------------------+-----------------------------+--------------+----------------------------+---------
# ...

# %%
spark.read.option("header",True) \
          .csv("P1075_92.csv") \
          .createOrReplaceTempView("p1075_92")  

spark.sql("SELECT * FROM p1075_92 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+------------------------
# ...

# %%
spark.read.option("header",True) \
          .csv("P1075_94.csv") \
          .createOrReplaceTempView("p1075_94")  

spark.sql("SELECT * FROM p1075_94 WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+------------------------
# ...

# %%
spark.read.option("header",True) \
          .csv("P0401_faults.csv") \
          .createOrReplaceTempView("p0401_faults")  

spark.sql("SELECT * FROM p0401_faults WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +-------+---------+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+--------------
# ...

# %%
spark.read.option("header",True) \
          .csv("P2457_faults.csv") \
          .createOrReplaceTempView("p2457_faults")  

spark.sql("SELECT * FROM p2457_faults WHERE _C0 IS NULL or _C0 = 'NA' or _C0 = '' or MESSAGE_ID IS NULL or MESSAGE_ID = '' or MESSAGE_ID = 'NA' or FAULT_DATE_TIME IS NULL or FAULT_DATE_TIME = '' or FAULT_DATE_TIME = 'NA' or FAULT_STATUS IS NULL or FAULT_STATUS = '' or FAULT_STATUS = 'NA' or VIN IS NULL or VIN = '' or VIN = 'NA' or length(VIN) != 17").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+------------------------
# ...

# %%
spark.sql("SELECT * FROM p1075_38 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p1075_75 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p1075_77 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p1075_86 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p1075_92 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p1075_94 WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p0401_faults WHERE VIN = '1M1AW01Y9FM007831'").show()
spark.sql("SELECT * FROM p2457_faults WHERE VIN = '1M1AW01Y9FM007831'").show()
# Out:
# +---+---+----------+---------------+------------------------+-------------------------+---------+----------+------------+--------------+------+--------+----------------+----------+----------+-----------------------+------------+------------------+----------------------------+--------------+----------------+-------------+------------------------------+-------------------------------+-------------------+-----------------------+-------------------------------+----------------+-----------------+------------+--------------+-----------------------------+-----------------------------+----------+------------------------------+---------------------------------+--------------------+------------------------+------------------------+-----------------------+------------------+--------------------+--------------------+-------------------------+----------------+---------------+----------+-----------------------------+--------------+----------------------------+-------------+------------------------
# ...

# %%
spark.read.option("header",True) \
          .csv("Population.csv") \
          .createOrReplaceTempView("population")

# %%
spark.sql('select VIN from population where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_38 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_75 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_77 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_86 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_92 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p1075_94 where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p0401_faults where VIN like "'"1M1AN02Y%"'"  ').show()
spark.sql('select distinct VIN from p2457_faults where VIN like "'"1M1AN02Y%"'"  ').show()
# Out:
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y5JM027293|
# |1M1AN02Y7JM027294|
# |1M1AN02Y1JM027257|
# |1M1AN02Y5JM027259|
# |1M1AN02Y1JM027260|
# |1M1AN02Y3JM027292|
# |1M1AN02Y3JM027258|
# |1M1AN02Y3JM027261|
# |1M1AN02Y9JM027295|
# |1M1AN02Y0JM027296|
# |1M1AN02Y5JM027309|
# |1M1AN02Y5JM028072|
# |1M1AN02Y3JM028068|
# |1M1AN02Y0JM028030|
# |1M1AN02Y3JM028071|
# |1M1AN02Y5JM028069|
# |1M1AN02Y2JM028093|
# |1M1AN02Y0JM028092|
# |1M1AN02Y1JM028070|
# |1M1AN02Y0KM028482|
# +-----------------+
# only showing top 20 rows
#
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y4JM028029|
# |1M1AN02Y9JM027295|
# |1M1AN02Y2JM028028|
# |1M1AN02Y0JM028027|
# |1M1AN02Y2JM028336|
# |1M1AN02Y7JM027294|
# |1M1AN02Y5JM027309|
# |1M1AN02Y0JM028335|
# |1M1AN02Y5KM028381|
# |1M1AN02YXJM027788|
# +-----------------+
#
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y0JM028335|
# |1M1AN02Y5KM028381|
# |1M1AN02Y0JM028318|
# ...

# %%
spark.sql('select VIN from population where VIN like "'"1M1AN02Y3KM027617%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_38 where VIN like "'"1M1AN02Y3KM027617%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_75 where VIN like "'"1M1AN02Y3KM027617%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_77 where VIN like "'"1M1AN02Y3KM027617%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_86 where VIN like "'"1M1AN02Y3KM027617%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_92 where VIN like "'"1M1AN02Y3KM027617%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p1075_94 where VIN like "'"1M1AN02Y3KM027617%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p0401_faults where VIN like "'"1M1AN02Y3KM027617%"'"  ').show()
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p2457_faults where VIN like "'"1M1AN02Y3KM027617%"'"  ').show()
# Out:
# +-----------------+
# |              VIN|
# +-----------------+
# |1M1AN02Y3KM027617|
# +-----------------+
#
# +---------------+------------+
# |FAULT_DATE_TIME|FAULT_STATUS|
# +---------------+------------+
# +---------------+------------+
#
# +---------------+------------+
# |FAULT_DATE_TIME|FAULT_STATUS|
# +---------------+------------+
# +---------------+------------+
#
# +---------------+------------+
# |FAULT_DATE_TIME|FAULT_STATUS|
# +---------------+------------+
# +---------------+------------+
#
# +---------------+------------+
# |FAULT_DATE_TIME|FAULT_STATUS|
# +---------------+------------+
# +---------------+------------+
#
# +-------------------+------------+
# |    FAULT_DATE_TIME|FAULT_STATUS|
# +-------------------+------------+
# |2020-12-02 18:16:14|           Y|
# |2020-12-04 00:59:43|           N|
# |2020-11-30 03:13:49|           N|
# |2020-11-28 22:06:18|           Y|
# +-------------------+------------+
#
# +-------------------+------------+
# ...

# %%
calculated_feature_names = [  "VIN",    
                              "calendar_day", 
                              "f_1_dtc38_1th_15d", 
                              "f_1_dtc38_2nd_15d", 
                              "f_2_dtc38_1th_15d", 
                              "f_2_dtc38_2nd_15d", 
                              "f_3_dtc38_1th_15d", 
                              "f_3_dtc38_2nd_15d", 
                              "f_4_dtc38_1th_15d", 
                              "f_4_dtc38_2nd_15d", 
                              "f_5_dtc38_1th_15d", 
                              "f_5_dtc38_2nd_15d", 
                              "f_6_dtc38_1th_15d", 
                              "f_6_dtc38_2nd_15d", 
                              "f_7_dtc38_1th_15d", 
                              "f_7_dtc38_2nd_15d", 
                              "f_8_dtc38_1th_15d", 
                              "f_8_dtc38_2nd_15d", 

                              "f_1_dtc75_1th_15d", 
                              "f_1_dtc75_2nd_15d", 
                              "f_2_dtc75_1th_15d", 
                              "f_2_dtc75_2nd_15d", 
                              "f_3_dtc75_1th_15d", 
                              "f_3_dtc75_2nd_15d", 
                              "f_4_dtc75_1th_15d", 
                              "f_4_dtc75_2nd_15d", 
                              "f_5_dtc75_1th_15d", 
                              "f_5_dtc75_2nd_15d", 
                              "f_6_dtc75_1th_15d", 
                              "f_6_dtc75_2nd_15d", 
                              "f_7_dtc75_1th_15d", 
                              "f_7_dtc75_2nd_15d", 
                              "f_8_dtc75_1th_15d", 
                              "f_8_dtc75_2nd_15d",


                              "f_1_dtc77_1th_15d", 
                              "f_1_dtc77_2nd_15d", 
                              "f_2_dtc77_1th_15d", 
                              "f_2_dtc77_2nd_15d", 
                              "f_3_dtc77_1th_15d", 
                              "f_3_dtc77_2nd_15d", 
                              "f_4_dtc77_1th_15d", 
                              "f_4_dtc77_2nd_15d", 
                              "f_5_dtc77_1th_15d", 
                              "f_5_dtc77_2nd_15d", 
                              "f_6_dtc77_1th_15d", 
                              "f_6_dtc77_2nd_15d", 
                              "f_7_dtc77_1th_15d", 
                              "f_7_dtc77_2nd_15d", 
                              "f_8_dtc77_1th_15d", 
                              "f_8_dtc77_2nd_15d",


                              "f_1_dtc86_1th_15d", 
                              "f_1_dtc86_2nd_15d", 
                              "f_2_dtc86_1th_15d", 
                              "f_2_dtc86_2nd_15d", 
                              "f_3_dtc86_1th_15d", 
                              "f_3_dtc86_2nd_15d", 
                              "f_4_dtc86_1th_15d", 
                              "f_4_dtc86_2nd_15d", 
                              "f_5_dtc86_1th_15d", 
                              "f_5_dtc86_2nd_15d", 
                              "f_6_dtc86_1th_15d", 
                              "f_6_dtc86_2nd_15d", 
                              "f_7_dtc86_1th_15d", 
                              "f_7_dtc86_2nd_15d", 
                              "f_8_dtc86_1th_15d", 
                              "f_8_dtc86_2nd_15d",


                              "f_1_dtc92_1th_15d", 
                              "f_1_dtc92_2nd_15d", 
                              "f_2_dtc92_1th_15d", 
                              "f_2_dtc92_2nd_15d", 
                              "f_3_dtc92_1th_15d", 
                              "f_3_dtc92_2nd_15d", 
                              "f_4_dtc92_1th_15d", 
                              "f_4_dtc92_2nd_15d", 
                              "f_5_dtc92_1th_15d", 
                              "f_5_dtc92_2nd_15d", 
                              "f_6_dtc92_1th_15d", 
                              "f_6_dtc92_2nd_15d", 
                              "f_7_dtc92_1th_15d", 
                              "f_7_dtc92_2nd_15d", 
                              "f_8_dtc92_1th_15d", 
                              "f_8_dtc92_2nd_15d",


                              "f_1_dtc94_1th_15d", 
                              "f_1_dtc94_2nd_15d", 
                              "f_2_dtc94_1th_15d", 
                              "f_2_dtc94_2nd_15d", 
                              "f_3_dtc94_1th_15d", 
                              "f_3_dtc94_2nd_15d", 
                              "f_4_dtc94_1th_15d", 
                              "f_4_dtc94_2nd_15d", 
                              "f_5_dtc94_1th_15d", 
                              "f_5_dtc94_2nd_15d", 
                              "f_6_dtc94_1th_15d", 
                              "f_6_dtc94_2nd_15d", 
                              "f_7_dtc94_1th_15d", 
                              "f_7_dtc94_2nd_15d", 
                              "f_8_dtc94_1th_15d", 
                              "f_8_dtc94_2nd_15d",


                              "f_1_dtc0401_1th_15d", 
                              "f_1_dtc0401_2nd_15d", 
                              "f_2_dtc0401_1th_15d", 
                              "f_2_dtc0401_2nd_15d", 
                              "f_3_dtc0401_1th_15d", 
                              "f_3_dtc0401_2nd_15d", 
                              "f_4_dtc0401_1th_15d", 
                              "f_4_dtc0401_2nd_15d", 
                              "f_5_dtc0401_1th_15d", 
                              "f_5_dtc0401_2nd_15d", 
                              "f_6_dtc0401_1th_15d", 
                              "f_6_dtc0401_2nd_15d", 
                              "f_7_dtc0401_1th_15d", 
                              "f_7_dtc0401_2nd_15d", 
                              "f_8_dtc0401_1th_15d", 
                              "f_8_dtc0401_2nd_15d",


                              "f_1_dtc2457_1th_15d", 
                              "f_1_dtc2457_2nd_15d", 
                              "f_2_dtc2457_1th_15d", 
                              "f_2_dtc2457_2nd_15d", 
                              "f_3_dtc2457_1th_15d", 
                              "f_3_dtc2457_2nd_15d", 
                              "f_4_dtc2457_1th_15d", 
                              "f_4_dtc2457_2nd_15d", 
                              "f_5_dtc2457_1th_15d", 
                              "f_5_dtc2457_2nd_15d", 
                              "f_6_dtc2457_1th_15d", 
                              "f_6_dtc2457_2nd_15d", 
                              "f_7_dtc2457_1th_15d", 
                              "f_7_dtc2457_2nd_15d", 
                              "f_8_dtc2457_1th_15d", 
                              "f_8_dtc2457_2nd_15d",

                              "if_parts_replaced_in_1th_15d", 
                              "if_parts_replaced_in_2nd_15d"]

# %%
df = spark.sql('select * from population where VIN like "'"1M1AW01Y9FM007831%"'"  ')   #.show()
# print(len(df.columns))
# y = df.toPandas().iloc[:,8:]
# df.printSchema()
df_population = spark.sql("SELECT * FROM population")
df_selected_features_from_population = [s for s in df_population.columns if 'KOLA' in s]+['VIN','ENGINE_SIZE','ENGINE_HP','VEH_TYPE']
list_of_all_selected_features_and_target = df_selected_features_from_population + calculated_feature_names


# list_selectedfeatures = np.array(pd.concat([pd.Series(x) for x in df_selectedfeatures], axis=1)).T.tolist()
# print(df_of_res)
print(list_of_all_selected_features_and_target)
# Out:
# ['_KOLA_01X', '_KOLA_02X', '_KOLA_03X', '_KOLA_04X', '_KOLA_05X', '_KOLA_06X', '_KOLA_07X', '_KOLA_08A', '_KOLA_08X', '_KOLA_09X', '_KOLA_0AX', '_KOLA_0BX', '_KOLA_0CX', '_KOLA_0DX', '_KOLA_0EA', '_KOLA_0EX', '_KOLA_0GX', '_KOLA_0HA', '_KOLA_0HX', '_KOLA_0JX', '_KOLA_0KX', '_KOLA_0LX', '_KOLA_0NX', '_KOLA_0PA', '_KOLA_0PX', '_KOLA_0RA', '_KOLA_0RX', '_KOLA_0SX', '_KOLA_15X', '_KOLA_19A', '_KOLA_1BX', '_KOLA_1CX', '_KOLA_1DA', '_KOLA_1DX', '_KOLA_1EA', '_KOLA_1GA', '_KOLA_1HA', '_KOLA_1JX', '_KOLA_1KX', '_KOLA_1LA', '_KOLA_1NX', '_KOLA_1PB', '_KOLA_1PX', '_KOLA_1QB', '_KOLA_1RB', '_KOLA_1RX', '_KOLA_1SB', '_KOLA_1SX', '_KOLA_1TX', '_KOLA_1UX', '_KOLA_1VX', '_KOLA_1YA', '_KOLA_1ZC', '_KOLA_20X', '_KOLA_21X', '_KOLA_24X', '_KOLA_26X', '_KOLA_28X', '_KOLA_2AC', '_KOLA_2BC', '_KOLA_2DX', '_KOLA_2JC', '_KOLA_2KX', '_KOLA_2MC', '_KOLA_2PB', '_KOLA_2PX', '_KOLA_2WX', '_KOLA_2XX', '_KOLA_31X', '_KOLA_34X', '_KOLA_36X', '_KOLA_38X', '_KOLA_39X', '_KOLA_3AX', '_KOLA_3FC', '_KOLA_3GC', '_KOLA_3G
# ...

# %%
spark.sql('select FAULT_DATE_TIME, FAULT_STATUS from p0401_faults where VIN like "'"1M1AN02Y3KM027617%"'"  ').sort(f.to_timestamp(f.col('FAULT_DATE_TIME'))).show()
df_dtc_type_for_this_VIN = spark.sql('select * from p0401_faults where VIN like "'"1M1AN02Y3KM027617%"'"  ').sort(f.to_timestamp(f.col('FAULT_DATE_TIME')))




dtc_type = "p0401_faults"
# Out:
# +-------------------+------------+
# |    FAULT_DATE_TIME|FAULT_STATUS|
# +-------------------+------------+
# |2018-12-30 02:48:32|           Y|
# |2018-12-30 03:28:02|           N|
# |2019-01-10 11:15:09|           Y|
# |2019-01-10 11:15:52|           N|
# |2019-01-25 09:23:34|           Y|
# |2019-01-25 09:25:40|           N|
# |2019-01-30 08:12:27|           Y|
# |2019-01-30 08:15:28|           N|
# |2019-10-23 04:19:15|           N|
# |2019-10-24 05:04:50|           Y|
# |2019-10-24 05:05:17|           N|
# |2019-10-30 21:00:38|           Y|
# |2019-10-30 22:46:59|           Y|
# |2019-10-30 22:50:50|           N|
# |2019-10-31 00:39:22|           Y|
# |2019-10-31 03:40:51|           Y|
# |2019-10-31 05:40:13|           Y|
# |2019-10-31 07:00:52|           Y|
# |2019-10-31 07:09:38|           N|
# |2019-10-31 07:17:50|           Y|
# +-------------------+------------+
# only showing top 20 rows

# %%
def fix_problem_of_fault_date_time_with_no_seconds(df, dtc_type):
    if dtc_type=="p1075_38":
       return f.to_timestamp(f.concat(df.FAULT_DATE_TIME, lit(":00")), "M/d/yyyy HH:mm:ss")
    else:
       return f.to_timestamp(df.FAULT_DATE_TIME, "yyyy-MM-dd HH:mm:ss")

# %%
which_15_days_back = "first"
dtc_status_to_calculate_this_feature = "I"
fault_date_time_format='yyyy-MM-dd HH:mm:ss'
if dtc_type=="p1075_38":
    fault_date_time_format='M/d/yyyy HH:mm'


duration_end_date = '2019-12-31'

day_delta = timedelta(days = 1)
split_date = duration_end_date.split('-')

end_date = date(int(split_date[0]), int(split_date[1]), int(split_date[2]))
start_date = end_date - timedelta(days = 65)
print ("start_date = {} and end_date = {} \n".format(start_date, end_date))
if df_dtc_type_for_this_VIN.count() > 0 :
#     df_dtc_type_for_this_VIN["_c0", "VIN","FAULT_STATUS", "FAULT_DATE_TIME", f.to_timestamp(f.col("FAULT_DATE_TIME"), fault_date_time_format)].show()
    df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan = df_dtc_type_for_this_VIN.filter((fix_problem_of_fault_date_time_with_no_seconds(df_dtc_type_for_this_VIN, dtc_type) > start_date) & (fix_problem_of_fault_date_time_with_no_seconds(df_dtc_type_for_this_VIN, dtc_type) < end_date))
    
    if df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan.count() > 0 :
        print("found number of DTC's that we want to calculate the duration for={}\n".format(df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan.count()))
        df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan = df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan.withColumn('dtc_alarms', f.concat(f.lit(which_15_days_back), f.lit("_15_days_back"))) 


        dtcs_with_all_statuses_df = df_dtc_type_for_this_VIN_any_dtc_status_in_this_timespan.alias("a").sort(f.to_timestamp(f.col("FAULT_DATE_TIME"), fault_date_time_format))
        # dtcs_with_all_statuses_df["_c0", "VIN","FAULT_STATUS", "FAULT_DATE_TIME", f.to_timestamp(f.col("FAULT_DATE_TIME"), fault_date_time_format)].show(195)


        dtcs_with_all_statuses_df2 = dtcs_with_all_statuses_df

    #     PsSpark: This one is also true to access the first row of pyspark dataframe    
    #     headRowId = dtcs_with_all_statuses_df2.first()[0]

        tailRowId = dtcs_with_all_statuses_df.tail(1)[0][0]
        print("tailRowId={}".format(tailRowId))
        dtcs_with_all_statuses_df = dtcs_with_all_statuses_df.filter(f.col('_c0') != tailRowId).fillna(0)
        dtcs_with_all_statuses_df = dtcs_with_all_statuses_df.sort(f.to_timestamp(f.col("FAULT_DATE_TIME"), fault_date_time_format)).withColumn("_c0",monotonically_increasing_id())
        dtcs_with_all_statuses_df = dtcs_with_all_statuses_df.dropna()
        dtcs_with_all_statuses_df = dtcs_with_all_statuses_df.withColumnRenamed("FAULT_STATUS", "FAULT_STATUS_CURRENT_DTC")
        dtcs_with_all_statuses_df = dtcs_with_all_statuses_df.withColumnRenamed("FAULT_DATE_TIME", "FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC")
    #     print("size after dropping tailRowId={}".format(dtcs_with_all_statuses_df.count()))
    #     dtcs_with_all_statuses_df["_c0", "VIN","FAULT_STATUS1", "FAULT_DATE_TIME1", f.to_timestamp(f.col("FAULT_DATE_TIME1"), fault_date_time_format)].show(dtcs_with_all_statuses_df.count())

        headRowId = dtcs_with_all_statuses_df2.head(1)[0][0]
        print("headRowId={}".format(headRowId))
        dtcs_with_all_statuses_df2 = dtcs_with_all_statuses_df2.filter(f.col('_c0') != headRowId).fillna(0)
        dtcs_with_all_statuses_df2 = dtcs_with_all_statuses_df2.sort(f.to_timestamp(f.col("FAULT_DATE_TIME"), fault_date_time_format)).withColumn("_c0",monotonically_increasing_id())
        dtcs_with_all_statuses_df2 = dtcs_with_all_statuses_df2.dropna()
        dtcs_with_all_statuses_df2 = dtcs_with_all_statuses_df2.withColumnRenamed("FAULT_STATUS", "FAULT_ANY_STATUS_NEXT_DTC")
        dtcs_with_all_statuses_df2 = dtcs_with_all_statuses_df2.withColumnRenamed("FAULT_DATE_TIME", "FAULT_DATE_TIME_NEXT_ANY_DTC")
        dtcs_with_all_statuses_df2 = dtcs_with_all_statuses_df2.select([c for c in dtcs_with_all_statuses_df2.columns if c != "VIN"])

    #     print("size after dropping headRowId={}".format(dtcs_with_all_statuses_df2.count()))
    #     dtcs_with_all_statuses_df2["_c0", "FAULT_STATUS2", "FAULT_DATE_TIME2", f.to_timestamp(f.col("FAULT_DATE_TIME2"), fault_date_time_format)].show(dtcs_with_all_statuses_df2.count())

    #   instead of deleting in PsSpark, we use below code to delet first and last rows in pandas   
    #     df1 = dtcs_with_all_statuses_df.toPandas()
    #     df1_minusEndRow = df1.iloc[:-1]  
    #     df1_minusEndRow = df1_minusEndRow.reset_index()
    #     df1_minusEndRow = df1_minusEndRow.dropna()
    #     print("Delete end row {}\n".format(df1_minusEndRow.count()))
    # #     display(df1_minusEndRow)


    #     df2 = dtcs_with_all_statuses_df.toPandas()
    #     df2_minusFirstRow = df2.iloc[1:]
    #     df2_minusFirstRow = df2_minusFirstRow.reset_index()
    #     df2_minusFirstRow = df2_minusFirstRow.dropna()
    #     print("Delete first row {}\n".format(df2_minusFirstRow.count()))
    # #     display(df2_minusFirstRow) 

        # create list of dataframes
        list_df = [dtcs_with_all_statuses_df, dtcs_with_all_statuses_df2]

        # merge all at once
        my_temp_df = reduce(lambda x, y: x.join(y, on="_c0"), list_df)
        my_temp_df = my_temp_df.withColumn("FAULT_DATE_TIME_DIFF", (f.unix_timestamp(f.col("FAULT_DATE_TIME_NEXT_ANY_DTC"), format=fault_date_time_format) - f.unix_timestamp(f.col("FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC"), format=fault_date_time_format))) \
        .withColumn("DURATION_IN_THIS_15_DAYS_BACK", f.when((f.to_timestamp(f.col("FAULT_DATE_TIME_NEXT_ANY_DTC"), fault_date_time_format) <= end_date) & 
                                                                      (f.to_timestamp(f.col("FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC"), fault_date_time_format) >= start_date), 
                                                                      (f.unix_timestamp("FAULT_DATE_TIME_NEXT_ANY_DTC", format=fault_date_time_format) - f.unix_timestamp("FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC", format=fault_date_time_format)))) \
        .withColumn("COUNT_IN_THIS_15_DAYS_BACK", f.when((f.to_timestamp(f.col("FAULT_DATE_TIME_NEXT_ANY_DTC"), fault_date_time_format) <= end_date) & 
                                                                      (f.to_timestamp(f.col("FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC"), fault_date_time_format) >= start_date), (f.lit(1)).cast(IntegerType())))
    #     my_temp_df["_c0", "VIN","FAULT_STATUS_CURRENT_DTC", "FAULT_ANY_STATUS_NEXT_DTC", "FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC", "FAULT_DATE_TIME_NEXT_ANY_DTC", f.to_timestamp(f.col("FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC"), fault_date_time_format), f.to_timestamp(f.col("FAULT_DATE_TIME_NEXT_ANY_DTC"), fault_date_time_format)].show(194)
        only_active_dtcs_df = my_temp_df.filter(f.col("FAULT_STATUS_CURRENT_DTC")==f.lit("Y"))
        only_active_dtcs_df["_c0", "VIN","FAULT_STATUS_CURRENT_DTC", "FAULT_ANY_STATUS_NEXT_DTC", "FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC", "FAULT_DATE_TIME_NEXT_ANY_DTC", "FAULT_DATE_TIME_DIFF", "DURATION_IN_THIS_15_DAYS_BACK", "COUNT_IN_THIS_15_DAYS_BACK", f.to_timestamp(f.col("FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC"), fault_date_time_format), f.to_timestamp(f.col("FAULT_DATE_TIME_NEXT_ANY_DTC"), fault_date_time_format)].show(only_active_dtcs_df.count())



        print("How many rows exists in the number of found DTCs starting with active status for this VIN = {} \n".format(only_active_dtcs_df.count()))
        duration_of_specific_type_dtcs_for_this_VIN = only_active_dtcs_df.select(f.sum("DURATION_IN_THIS_15_DAYS_BACK")).fillna(0)
        count_of_specific_type_dtcs_for_this_VIN = only_active_dtcs_df.select(f.sum("COUNT_IN_THIS_15_DAYS_BACK")).fillna(1)
        duration = duration_of_specific_type_dtcs_for_this_VIN.collect()[0][0]
        print("The duration is equal to {}\n".format(duration))

        total_count = count_of_specific_type_dtcs_for_this_VIN.collect()[0][0]
        if(total_count != 0):
            print("The duration is equal to {}\n".format(duration))  
            average_of_specific_type_dtcs_for_this_VIN = duration/total_count
            print("The average is equal to {}\n".format(average_of_specific_type_dtcs_for_this_VIN))
        else:
            print("The average is equal to zero\n")

    else:
        print("Thee average/duration are equal to zero\n")
else: 
    print("The average/duration are equal to zero\n")
# Out:
# start_date = 2019-10-27 and end_date = 2019-12-31
#
# found number of DTC's that we want to calculate the duration for=113
#
# tailRowId=2716817
# headRowId=3098605
# +---+-----------------+------------------------+-------------------------+-----------------------------------------+----------------------------+--------------------+-----------------------------+--------------------------+----------------------------------------------------------------------------+---------------------------------------------------------------+
# |_c0|              VIN|FAULT_STATUS_CURRENT_DTC|FAULT_ANY_STATUS_NEXT_DTC|FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC|FAULT_DATE_TIME_NEXT_ANY_DTC|FAULT_DATE_TIME_DIFF|DURATION_IN_THIS_15_DAYS_BACK|COUNT_IN_THIS_15_DAYS_BACK|to_timestamp(FAULT_DATE_TIME_CURRENT_SPECIFIC_TYPE_DTC, yyyy-MM-dd HH:mm:ss)|to_timestamp(FAULT_DATE_TIME_NEXT_ANY_DTC, yyyy-MM-dd HH:mm:ss)|
# ...
